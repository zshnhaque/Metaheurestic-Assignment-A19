,	-406.65812933834798000000	,	165.86565911129765000000	,	-599.72619253005837000000	,	-197.24046797739567000000	,	-269.88021424054682000000	,	-546.56697552956371000000	,	-487.32420288319304000000	,	-108.00312027356705000000	,	380.27078339274510000000	,	444.62048617118330000000	,	-572.93385545276533000000	,	272.61238043751814000000	,	417.61133767674755000000	,	274.32022922162832000000	,	546.11835993016189000000	,	187.62133271622940000000	,	290.76616021086875000000	,	-186.04078331649509000000	,	460.82633961018178000000	,	-183.30709620094427000000	,	-528.62798334897298000000	,	262.09750929530412000000	,	549.85715148888812000000])

# %%
f_bias = np.array([ -450.0 , -450.0 , 390.0 , -330.0 , -180.0 , -140.0])

# %%
class shifted_griewank_problem:
    def __init__(self, dim):
        self.dim = dim
    def fitness(self, x):
        sum_val = np.zeros((1,))
        prod_val = np.ones((1,))
        fitness_val = np.zeros((1,))
        for i in range(len(x)):
            prod_val[0] = prod_val[0] * np.cos((x[i]- griewank[i])/np.sqrt(i+1))
            sum_val[0] = sum_val[0] + np.power((x[i]-griewank[i]),2)/4000
        fitness_val[0] = sum_val[0] - prod_val[0] + f_bias[4] +1
        return fitness_val
    def get_bounds(self):
        return (np.full((self.dim,),-600),np.full((self.dim,),600))
    def get_name(self):
        return "Shifted Griewank Function"
    def get_extra_info(self):
        return "\tDimensions: " + str(self.dim)

# %%
def algo_particle_swarm_opt(gen=50):
    pso_algo_obj = pg.algorithm(pg.pso(gen = gen))
    return pso_algo_obj

# %%
def algo_simulated_annealing_fn(Ts_val,Tf_val):
    sa_algo_obj = pg.algorithm(pg.simulated_annealing(Ts=Ts_val, Tf=Tf_val))
    return sa_algo_obj

# %%
def aglo_differential_evolution_fn(gen_val=100, f_val=0.8):
    de_algo_obj = pg.algorithm(pg.de(gen=gen_val, F=f_val))
    return de_algo_obj

# %%
def algo_cmaes_fn(gen_val=500,c1_val = -1):
    cmaes_algo_obj = pg.algorithm(pg.cmaes(gen=gen_val,c1=c1_val))
    return cmaes_algo_obj

# %%
def population_init_fn(prob_obj,pop_size):
    pop_obj = pg.population(prob_obj,size = pop_size,seed=123)
    return pop_obj

# %%
SGrei_50 = shifted_griewank_problem(50)
SGrei_500 = shifted_griewank_problem(500)

# %%
def calc_fitness(iteration,algo_obj,problem_obj,pg_population_size):
    tick = time.time()
    fitness_val = []
    pop_obj = []
    pop = population_init_fn(problem_obj,pg_population_size)
    for i in range(iteration):
        val = (i,pop.champion_f,time.time()-tick)
        fitness_val.append(val)
        pop_obj.append(pop)
        pop = algo_obj.evolve(pop)

    return (fitness_val,pop_obj)

# %%
sa_algo = algo_simulated_annealing_fn(1000,0.01)
cames_algo = algo_cmaes_fn()
pso_algo = algo_particle_swarm_opt()
de_algo = aglo_differential_evolution_fn()

# %%
test1 = calc_fitness(100,aglo_differential_evolution_fn(),SGrei_50,100)

# %%
test1
# Out:
# ([(0, array([2146.40884237]), 0.023936033248901367),
#   (1, array([215.45898955]), 2.4664080142974854),
#   (2, array([-30.15456923]), 4.88494348526001),
#   (3, array([-118.31755606]), 7.2835328578948975),
#   (65, array([-179.99999941]), 86.5895631313324),
#   (66, array([-179.99999941]), 86.61649084091187),
#   (67, array([-179.99999947]), 86.64242172241211),
#   (68, array([-179.99999947]), 86.66835284233093),
#   (69, array([-179.99999947]), 86.69528007507324),
#   (70, array([-179.99999947]), 86.72121119499207),
#   (71, array([-179.99999947]), 86.74714159965515),
#   (72, array([-179.99999947]), 86.7740695476532),
#   (73, array([-179.99999947]), 86.8000009059906),
#   (74, array([-179.99999947]), 86.82593107223511),
#   (75, array([-179.99999947]), 86.85285925865173),
#   (76, array([-179.99999949]), 86.87978744506836),
#   (77, array([-179.99999949]), 86.9067153930664),
#   (78, array([-179.99999949]), 86.93364310264587),
#   (79, array([-179.99999949]), 86.9605712890625),
#   (80, array([-179.99999949]), 86.98849654197693),
#   (81, array([-179.99999949]), 87.01642179489136),
#   (82, array([-179.99999949]), 87.04335069656372),
#   (83, array([-179.99999949]), 87.07027864456177),
#   (84, array([-179.99999949]), 87.09820365905762),
#   (85, array([-179.99999949]), 87.12612867355347),
#   (86, array([-179.99999949]), 87.15505242347717),
#   (87, array([-179.99999949]), 87.18297791481018),
#   (88, array([-179.99999955]), 87.2109022140503),
#   (89, array([-179.99999958]), 87.23882794380188),
#   (90, array([-179.99999958]), 87.26775026321411),
#   (91, array([-179.99999958]), 87.29567551612854),
#   (92, array([-179.99999958]), 87.32360053062439),
#   (93, array([-179.99999958]), 87.34953188896179),
#   (94, array([-179.99999958]), 87.37645983695984),
#   (95, array([-179.99999958]), 87.40338778495789),
#   (96, array([-179.99999958]), 87.43131279945374),
#   (97, array([-179.99999958]), 87.45724391937256),
#   (98, array([-179.99999958]), 87.48417139053345),
#   (99, array([-179.99999958]), 87.51010251045227)],
#  [Problem name: Shifted Griewank Function
#   	Global dimension:			50
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 100
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 50
#   Population size: 100
#
#   List of individuals:
#   #0:
#   	ID:			2225206138463043340
#   	Decision vector:	[255.546, -85.8349, 229.062, 262.98, -10.6573, ... ]
#   	Fitness vector:		[2673.07]
#   #1:
#   	ID:			12297052430986820814
#   	Decision vector:	[357.274, -260.756, -79.8981, -588.291, -191.045, ... ]
#   	Fitness vector:		[2517.14]
#   #2:
#   	ID:			5285667643970941218
#   	Decision vector:	[-311.703, 461.766, -47.7139, -368.196, -247.569, ... ]
#   	Fitness vector:		[3081.27]
#   #3:
#   	ID:			18374549529275722835
#   	Decision vector:	[591.136, -113.778, -371.792, -14.1906, 2.84357, ... ]
#   	Fitness vector:		[2186.98]
#   #4:
#   	ID:			3523456383179486427
#   	Decision vector:	[13.5809, 504.601, -235.243, -8.39672, 575.232, ... ]
#   	Fitness vector:		[2639.9]
#   #5:
#   	ID:			16143198337935166698
#   	Decision vector:	[254.991, 220.339, 535.945, 495.878, -538.494, ... ]
#   	Fitness vector:		[2499.16]
#   #6:
#   	ID:			2679642930772534122
#   	Decision vector:	[-174.116, 258.308, 153.938, 561.014, -262.299, ... ]
#   	Fitness vector:		[3137.69]
#   #7:
#   	ID:			8926177331335096686
#   	Decision vector:	[50.3633, 96.0628, -513.091, 215.323, 264.427, ... ]
#   	Fitness vector:		[2388.13]
#   #8:
#   	ID:			13085856269157907389
#   	Decision vector:	[97.4282, 302.742, -125.347, -40.9971, 348.937, ... ]
#   	Fitness vector:		[2854.04]
#   #9:
#   	ID:			9548467525468391450
#   	Decision vector:	[-125.882, -36.7113, 131.597, 385.58, -22.6488, ... ]
#   	Fitness vector:		[2796.13]
#   #10:
#   	ID:			11943021808861229888
#   	Decision vector:	[-108.227, -235.201, 576.68, 409.07, 335.486, ... ]
#   	Fitness vector:		[2146.41]
#   #11:
#   	ID:			3542330960622651304
#   	Decision vector:	[461.479, -171.529, -213.845, -447.593, 393.385, ... ]
#   	Fitness vector:		[2704.32]
#   #12:
#   	ID:			4202206382085644130
#   	Decision vector:	[-390.907, 409.881, 503.731, -400.682, 305.358, ... ]
#   	Fitness vector:		[2873.65]
#   #13:
#   	ID:			3184124607595428052
#   	Decision vector:	[-260.474, 139.074, -66.2924, 586.94, 267.814, ... ]
#   	Fitness vector:		[3029.05]
#   #14:
#   	ID:			13936042818324245572
#   	Decision vector:	[243.649, -55.7673, 44.3659, 76.4104, -317.291, ... ]
#   	Fitness vector:		[2457.24]
#   #15:
#   	ID:			8949426634201417972
#   	Decision vector:	[23.7452, 349.437, -554.251, 33.974, -566.285, ... ]
#   	Fitness vector:		[2935.33]
#   #16:
#   	ID:			12078054439952405508
#   	Decision vector:	[-158.546, -457.934, 325.049, -76.5503, -128.337, ... ]
#   	Fitness vector:		[2383.29]
#   #17:
#   	ID:			13894167959374236419
#   	Decision vector:	[354.871, 380.72, 182.29, 468.053, -545.202, ... ]
#   	Fitness vector:		[3222.99]
#   #18:
#   	ID:			8362760210316625397
#   	Decision vector:	[-301.367, -202.43, -376.184, 300.559, 442.538, ... ]
#   	Fitness vector:		[3019.29]
#   #19:
#   	ID:			7196541724872274580
#   	Decision vector:	[488.717, -408.686, 2.43442, 187.772, 532.592, ... ]
#   	Fitness vector:		[2165.15]
#   #20:
#   	ID:			1550932363424780449
#   	Decision vector:	[371.719, 82.2516, 275.487, -13.1768, -13.967, ... ]
#   	Fitness vector:		[2700.17]
#   #21:
#   	ID:			6888248217719895857
#   	Decision vector:	[205.657, -242.745, -75.6353, 420.943, 90.5073, ... ]
#   	Fitness vector:		[2694.25]
#   #22:
#   	ID:			12663017763644598570
#   	Decision vector:	[-222.036, 205.063, -431.253, 176.906, -272.465, ... ]
#   	Fitness vector:		[3637.3]
#   #23:
#   	ID:			8578079531890885389
#   	Decision vector:	[6.96345, -517.568, -491.539, 448.782, -348.127, ... ]
#   	Fitness vector:		[2543.13]
#   #24:
#   	ID:			13940206447630858189
#   	Decision vector:	[88.5121, 513.906, 356.014, 182.086, -128.322, ... ]
#   	Fitness vector:		[2392.07]
#   #25:
#   	ID:			1086177176438975582
#   	Decision vector:	[-177.284, 0.00580495, 332.362, 580.31, -265.392, ... ]
#   	Fitness vector:		[2813.56]
#   #26:
#   	ID:			10883301874930944361
#   	Decision vector:	[-481.369, -461.996, -123.695, 352.323, 168.746, ... ]
#   	Fitness vector:		[3191.04]
#   #27:
#   	ID:			15960943583987012692
#   	Decision vector:	[-553.486, 226.299, 442.167, 565.976, -284.489, ... ]
#   	Fitness vector:		[3413.51]
#   #28:
#   	ID:			10406297328975478953
#   	Decision vector:	[454.677, -209.621, -553.593, 558.531, -93.8463, ... ]
#   	Fitness vector:		[2895.68]
#   #29:
#   	ID:			3676954230463352713
#   	Decision vector:	[-196.381, 244.192, -249.167, 91.4302, 196.65, ... ]
#   	Fitness vector:		[3298.1]
#   #30:
#   	ID:			3991290275743728752
#   	Decision vector:	[-148.77, 507.109, -13.8721, 305.916, -513.512, ... ]
#   	Fitness vector:		[2846.71]
#   #31:
#   	ID:			16981369922356100525
#   	Decision vector:	[-580.201, 57.2307, -249.325, -337.362, -76.7061, ... ]
#   	Fitness vector:		[2958.76]
#   #32:
#   	ID:			9049504384480694738
#   	Decision vector:	[53.9924, -262.57, 66.9313, -115.785, 481.93, ... ]
#   	Fitness vector:		[2350.08]
#   #33:
#   	ID:			15665871201088247711
#   	Decision vector:	[-519.025, -288.12, -114.337, 86.4523, -71.8147, ... ]
#   	Fitness vector:		[2887.58]
#   #34:
#   	ID:			8395429812993607298
#   	Decision vector:	[-490.427, 563.242, -506.302, 367.077, -542.936, ... ]
#   	Fitness vector:		[3551.71]
#   #35:
#   	ID:			17427233450009322150
#   	Decision vector:	[-200.555, 21.6716, 299.338, -400.187, 358.765, ... ]
#   	Fitness vector:		[3514.8]
#   #36:
#   	ID:			13397309235255809997
#   	Decision vector:	[-100.414, -588.224, -487.89, 235.53, 81.4966, ... ]
#   	Fitness vector:		[2949.82]
#   #37:
#   	ID:			7514736503523423908
#   	Decision vector:	[-539.838, 88.4114, -262.199, -179.645, -187.179, ... ]
#   	Fitness vector:		[2619.24]
#   #38:
#   	ID:			7744491533144990262
#   	Decision vector:	[490.548, 142.674, 421.674, 35.7812, -42.5324, ... ]
#   	Fitness vector:		[2906.76]
#   #39:
#   	ID:			11536841766837987056
#   	Decision vector:	[152.505, 156.749, 353.142, -215.792, -346.769, ... ]
#   	Fitness vector:		[2160.72]
#   #40:
#   	ID:			17240239183589772811
#   	Decision vector:	[1.22096, -48.5319, 492.314, 43.6915, -530.986, ... ]
#   	Fitness vector:		[2432.44]
#   #41:
#   	ID:			9155702560218266538
#   	Decision vector:	[25.4772, 421.213, -291.238, -36.8576, -123.769, ... ]
#   	Fitness vector:		[2252.39]
#   #42:
#   	ID:			15884582255490642572
#   	Decision vector:	[83.5447, 130.36, -335.684, 450.854, 165.712, ... ]
#   	Fitness vector:		[3433.1]
#   #43:
#   	ID:			9802089293239498402
#   	Decision vector:	[129.949, 186.179, -417.834, 25.2351, 269.861, ... ]
#   	Fitness vector:		[2964.76]
#   #44:
#   	ID:			1247796552286349558
#   	Decision vector:	[-70.4461, 578.17, -328.101, 480.82, -359.148, ... ]
#   	Fitness vector:		[2821.47]
#   #45:
#   	ID:			2411011014636967255
#   	Decision vector:	[594.973, 394.545, -39.26, -292.493, -59.4655, ... ]
#   	Fitness vector:		[3043.4]
#   #46:
#   	ID:			512830168174338560
#   	Decision vector:	[-279.011, -361.736, 453.829, 4.94117, 84.2361, ... ]
#   	Fitness vector:		[3168.17]
#   #47:
#   	ID:			12395682245797912363
#   	Decision vector:	[-271.245, 34.909, -146.328, 149.56, -127.184, ... ]
#   	Fitness vector:		[2668.78]
#   #48:
#   	ID:			1043750935261532435
#   	Decision vector:	[94.0828, 158.386, 507.692, -199.431, 101.637, ... ]
#   	Fitness vector:		[2793.58]
#   #49:
#   	ID:			15996207456514142779
#   	Decision vector:	[363.395, 84.3623, -119.16, 168.214, -404.992, ... ]
#   	Fitness vector:		[3162.05]
#   #50:
#   	ID:			7229535937762185213
#   	Decision vector:	[-30.2308, 237.485, -425.609, 178.949, -469.285, ... ]
#   	Fitness vector:		[2839.13]
#   #51:
#   	ID:			14043892262923552714
#   	Decision vector:	[-161.348, -148.142, -586.761, -66.3304, -138.907, ... ]
#   	Fitness vector:		[3219.79]
#   #52:
#   	ID:			4094938435936059159
#   	Decision vector:	[-329.497, -178.458, 49.4288, 85.863, 212.906, ... ]
#   	Fitness vector:		[2621.62]
#   #53:
#   	ID:			1912221584581384952
#   	Decision vector:	[440.434, 258.5, -134.185, -142.068, -350.433, ... ]
#   	Fitness vector:		[3156.31]
#   #54:
#   	ID:			2701496665568203459
#   	Decision vector:	[89.0546, 258.533, -585.947, -579.457, -14.3577, ... ]
#   	Fitness vector:		[3057.12]
#   #55:
#   	ID:			10784724986759222419
#   	Decision vector:	[-464.162, -54.7419, 171.506, 137.723, -33.569, ... ]
#   	Fitness vector:		[2275.88]
#   #56:
#   	ID:			11672797991117284350
#   	Decision vector:	[416.64, 319.017, -223.282, 165.009, 553.452, ... ]
#   	Fitness vector:		[2693.99]
#   #57:
#   	ID:			16449973265539317921
#   	Decision vector:	[336.429, -473.871, -108.806, -244.213, -221.5, ... ]
#   	Fitness vector:		[2830.59]
#   #58:
#   	ID:			4310301120224420839
#   	Decision vector:	[-475.081, -220.436, -407.9, 537.775, 562.53, ... ]
#   	Fitness vector:		[3362.3]
#   #59:
#   	ID:			11897016052137519835
#   	Decision vector:	[451.054, 58.7314, 424.541, 278.392, 143.577, ... ]
#   	Fitness vector:		[3187.97]
#   #60:
#   	ID:			16283123593384966060
#   	Decision vector:	[-361.124, 199.564, 374.606, 556.447, 125.539, ... ]
#   	Fitness vector:		[2468.86]
#   #61:
#   	ID:			6041918823320825202
#   	Decision vector:	[460.062, -283.629, -480.537, 312.631, -104.607, ... ]
#   	Fitness vector:		[2662.31]
#   #62:
#   	ID:			13582905386853642257
#   	Decision vector:	[-299.832, -81.6566, 539.971, -489.652, -268.817, ... ]
#   	Fitness vector:		[3689.01]
#   #63:
#   	ID:			13993795930535283000
#   	Decision vector:	[124.273, 84.1447, -547.071, -50.7478, 509.474, ... ]
#   	Fitness vector:		[3023.6]
#   #64:
#   	ID:			16443466038036687211
#   	Decision vector:	[-488.182, -526.634, 153.709, 11.7446, -172.959, ... ]
#   	Fitness vector:		[3671.55]
#   #65:
#   	ID:			15799160394448242879
#   	Decision vector:	[-268.422, 153.602, 47.0167, -346.707, -106.258, ... ]
#   	Fitness vector:		[2647.5]
#   #66:
#   	ID:			1502837664918511572
#   	Decision vector:	[66.0461, -516.635, -472.069, 104.496, -505.386, ... ]
#   	Fitness vector:		[2862.78]
#   #67:
#   	ID:			8701733356748298325
#   	Decision vector:	[337.575, 21.8574, -327.996, 201.242, 105.331, ... ]
#   	Fitness vector:		[2686.34]
#   #68:
#   	ID:			14626185667690627571
#   	Decision vector:	[463.843, -116.304, 168, 337.185, 82.4103, ... ]
#   	Fitness vector:		[2596.69]
#   #69:
#   	ID:			13890480263780897966
#   	Decision vector:	[-146.608, -276.83, 139.065, -599.225, 104.289, ... ]
#   	Fitness vector:		[2691.46]
#   #70:
#   	ID:			13720150016270389834
#   	Decision vector:	[-559.93, 507.971, -481.652, -508.598, 88.5639, ... ]
#   	Fitness vector:		[2635.83]
#   #71:
#   	ID:			104056975415421551
#   	Decision vector:	[-94.282, -186.793, -491.266, 51.9976, -240.022, ... ]
#   	Fitness vector:		[3017.41]
#   #72:
#   	ID:			15959386665064133613
#   	Decision vector:	[220.565, 468.347, 526.466, -575.292, 552.567, ... ]
#   	Fitness vector:		[2685.42]
#   #73:
#   	ID:			4140779234101294551
#   	Decision vector:	[-64.9111, -390.825, -514.845, -22.2736, -291.316, ... ]
#   	Fitness vector:		[2915.04]
#   #74:
#   	ID:			5780724163403000096
#   	Decision vector:	[-23.0654, 163.493, 466.821, 226.772, 578.014, ... ]
#   	Fitness vector:		[2941.94]
#   #75:
#   	ID:			9869926242304591943
#   	Decision vector:	[-29.4474, 374.594, -455.059, 106.672, -143.649, ... ]
#   	Fitness vector:		[3625.33]
#   #76:
#   	ID:			13677810612207885889
#   	Decision vector:	[-88.257, 350.44, 452.687, -507.867, -519.721, ... ]
#   	Fitness vector:		[3531.69]
#   #77:
#   	ID:			3663926790231072014
#   	Decision vector:	[417.963, -147.457, -395.296, 163.537, 365.101, ... ]
#   	Fitness vector:		[2476.41]
#   #78:
#   	ID:			11748941366581064079
#   	Decision vector:	[266.929, 307.094, 127.936, 459.265, 155.547, ... ]
#   	Fitness vector:		[2971.5]
#   #79:
#   	ID:			1834885002265901748
#   	Decision vector:	[195.182, 3.80415, 459.014, 346.599, -521.037, ... ]
#   	Fitness vector:		[2894.99]
#   #80:
#   	ID:			5362772216456720486
#   	Decision vector:	[544.156, -80.2377, -370.709, 410.842, 414.875, ... ]
#   	Fitness vector:		[2214.1]
#   #81:
#   	ID:			1354448177322124209
#   	Decision vector:	[-69.3357, 222.936, 558.825, -434.797, -162.984, ... ]
#   	Fitness vector:		[2158.65]
#   #82:
#   	ID:			17623829949309168833
#   	Decision vector:	[-164.006, -565.667, 267.736, 129.119, -48.3111, ... ]
#   	Fitness vector:		[3928.9]
#   #83:
#   	ID:			5183649184466607690
#   	Decision vector:	[-263.289, 128.433, 83.7592, -11.9087, -520.166, ... ]
#   	Fitness vector:		[2604.53]
#   #84:
#   	ID:			3200411107488405488
#   	Decision vector:	[321.094, -359.053, -495.232, -244.174, -509.412, ... ]
#   	Fitness vector:		[3509.46]
#   #85:
#   	ID:			7112655227198101231
#   	Decision vector:	[-127.141, -297.498, -119.148, 364.376, 11.7496, ... ]
#   	Fitness vector:		[3099.57]
#   #86:
#   	ID:			1637449397291609376
#   	Decision vector:	[-471.321, 365.623, 375.658, -263.421, -280.521, ... ]
#   	Fitness vector:		[2885.88]
#   #87:
#   	ID:			15171478455142479384
#   	Decision vector:	[-258.023, 81.5547, -447.666, 521.273, 323.583, ... ]
#   	Fitness vector:		[2584.37]
#   #88:
#   	ID:			10301090294912487902
#   	Decision vector:	[224.137, -242.893, -473.938, -574.992, 442.493, ... ]
#   	Fitness vector:		[2638.52]
#   #89:
#   	ID:			6676980116969800596
#   	Decision vector:	[-470.901, -239.436, 564.042, 446.587, 537.228, ... ]
#   	Fitness vector:		[3221.57]
#   #90:
#   	ID:			8396422725058707169
#   	Decision vector:	[504.889, -529.252, -383.04, 159.674, 48.5867, ... ]
#   	Fitness vector:		[2434.22]
#   #91:
#   	ID:			1859076449795172048
#   	Decision vector:	[440.275, -142.197, -105.153, -399.884, -465.977, ... ]
#   	Fitness vector:		[2542.26]
#   #92:
#   	ID:			16531750522682343483
#   	Decision vector:	[-233.929, -391.652, -11.7283, -590.126, -302.571, ... ]
#   	Fitness vector:		[2881.35]
#   #93:
#   	ID:			1348316913162031876
#   	Decision vector:	[189.959, -343.605, 132.567, 348.377, -176.556, ... ]
#   	Fitness vector:		[2302.78]
#   #94:
#   	ID:			6505260245021410976
#   	Decision vector:	[-104.139, 52.0703, -587.775, -425.451, 25.5537, ... ]
#   	Fitness vector:		[2741.48]
#   #95:
#   	ID:			1813999754814952482
#   	Decision vector:	[-25.1475, -83.7958, -486.561, -568.002, -445.006, ... ]
#   	Fitness vector:		[3330.02]
#   #96:
#   	ID:			12358421756577092511
#   	Decision vector:	[-277.29, 347.714, -221.517, -350.395, -489.1, ... ]
#   	Fitness vector:		[2847.84]
#   #97:
#   	ID:			7962062347785663431
#   	Decision vector:	[592.736, -241.315, 147.297, 101.185, 594.267, ... ]
#   	Fitness vector:		[2280.24]
#   #98:
#   	ID:			12922584347166259754
#   	Decision vector:	[-66.7741, 471.871, -155.43, 310.874, 8.39319, ... ]
#   	Fitness vector:		[2402.81]
#   #99:
#   	ID:			6264273121927259993
#   	Decision vector:	[-265.302, -132.039, 458.284, 214.275, -265.131, ... ]
#   	Fitness vector:		[3770.42]
#
#   Champion decision vector: [-108.227, -235.201, 576.68, 409.07, 335.486, ... ]
#   Champion fitness: [2146.41],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			50
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 10100
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 50
#   Population size: 100
#
#   List of individuals:
#   #0:
#   	ID:			2225206138463043340
#   	Decision vector:	[510.451, -195.302, 147.979, -84.1525, 506.179, ... ]
#   	Fitness vector:		[283.894]
#   #1:
#   	ID:			12297052430986820814
#   	Decision vector:	[445.19, -143.637, -11.7603, 119.01, 548.933, ... ]
#   	Fitness vector:		[310.355]
#   #2:
#   	ID:			5285667643970941218
#   	Decision vector:	[397.323, -382.047, 501.687, -161.92, 477.953, ... ]
#   	Fitness vector:		[425.903]
#   #3:
#   	ID:			18374549529275722835
#   	Decision vector:	[397.923, -217.474, 442.975, -203.578, 543.502, ... ]
#   	Fitness vector:		[535.13]
#   #4:
#   	ID:			3523456383179486427
#   	Decision vector:	[398.364, -95.7964, -8.32382, -132.893, 76.4028, ... ]
#   	Fitness vector:		[303.641]
#   #5:
#   	ID:			16143198337935166698
#   	Decision vector:	[542.053, -133.127, 453.306, -165.271, 97.2273, ... ]
#   	Fitness vector:		[534.688]
#   #6:
#   	ID:			2679642930772534122
#   	Decision vector:	[294.592, -396.092, -65.2106, -34.4691, 576.075, ... ]
#   	Fitness vector:		[407.556]
#   #7:
#   	ID:			8926177331335096686
#   	Decision vector:	[533.594, -110.575, -171.254, 129.428, 469.851, ... ]
#   	Fitness vector:		[272.668]
#   #8:
#   	ID:			13085856269157907389
#   	Decision vector:	[467.248, -92.5414, 272.389, -2.58293, 484.522, ... ]
#   	Fitness vector:		[313.143]
#   #9:
#   	ID:			9548467525468391450
#   	Decision vector:	[306.876, -561.24, 226.191, -258.062, 277.619, ... ]
#   	Fitness vector:		[394.91]
#   #10:
#   	ID:			11943021808861229888
#   	Decision vector:	[353, -421.349, -169.005, 378.585, 318.647, ... ]
#   	Fitness vector:		[407.705]
#   #11:
#   	ID:			3542330960622651304
#   	Decision vector:	[387.082, 14.8595, 215.989, 197.048, 441.074, ... ]
#   	Fitness vector:		[283.451]
#   #12:
#   	ID:			4202206382085644130
#   	Decision vector:	[291.137, -416.287, 206.182, -275.534, 501.103, ... ]
#   	Fitness vector:		[311.314]
#   #13:
#   	ID:			3184124607595428052
#   	Decision vector:	[399.442, -535.782, -18.2415, 293.204, 200.106, ... ]
#   	Fitness vector:		[316.449]
#   #14:
#   	ID:			13936042818324245572
#   	Decision vector:	[522.758, -312.371, -71.1719, -8.58596, 309.703, ... ]
#   	Fitness vector:		[272.421]
#   #15:
#   	ID:			8949426634201417972
#   	Decision vector:	[188.782, -411.39, -56.7694, 391.018, 531.499, ... ]
#   	Fitness vector:		[444.536]
#   #16:
#   	ID:			12078054439952405508
#   	Decision vector:	[-137.918, -202.373, -0.421698, -213.368, 496.979, ... ]
#   	Fitness vector:		[390.219]
#   #17:
#   	ID:			13894167959374236419
#   	Decision vector:	[377.355, -509.407, 2.06321, -63.4935, 251.251, ... ]
#   	Fitness vector:		[343.512]
#   #18:
#   	ID:			8362760210316625397
#   	Decision vector:	[551.272, -281.075, 42.2238, -357.097, 497.606, ... ]
#   	Fitness vector:		[522.706]
#   #19:
#   	ID:			7196541724872274580
#   	Decision vector:	[410.766, -426.886, 63.5607, -251.526, 390.591, ... ]
#   	Fitness vector:		[270.392]
#   #20:
#   	ID:			1550932363424780449
#   	Decision vector:	[453.834, -563.147, -111.986, -435.65, 220.387, ... ]
#   	Fitness vector:		[433.286]
#   #21:
#   	ID:			6888248217719895857
#   	Decision vector:	[336.614, -366.41, 158.151, -15.6122, 597.841, ... ]
#   	Fitness vector:		[401.649]
#   #22:
#   	ID:			12663017763644598570
#   	Decision vector:	[565.568, -250.062, -52.4182, -176.929, 125.919, ... ]
#   	Fitness vector:		[486.518]
#   #23:
#   	ID:			8578079531890885389
#   	Decision vector:	[501.456, -432.309, 185.812, 81.7654, 574.592, ... ]
#   	Fitness vector:		[415.225]
#   #24:
#   	ID:			13940206447630858189
#   	Decision vector:	[469.5, -302.841, 67.7853, 293.591, -120.106, ... ]
#   	Fitness vector:		[498.867]
#   #25:
#   	ID:			1086177176438975582
#   	Decision vector:	[342.619, -67.1348, 169.283, 497.674, 379.336, ... ]
#   	Fitness vector:		[314.151]
#   #26:
#   	ID:			10883301874930944361
#   	Decision vector:	[341.172, -290.088, 117.991, 87.0446, 402.295, ... ]
#   	Fitness vector:		[354.077]
#   #27:
#   	ID:			15960943583987012692
#   	Decision vector:	[351.329, -339.692, 82.6209, -106.132, 407.317, ... ]
#   	Fitness vector:		[353.408]
#   #28:
#   	ID:			10406297328975478953
#   	Decision vector:	[206.681, -553.24, -179.098, 385.01, 458.328, ... ]
#   	Fitness vector:		[520.934]
#   #29:
#   	ID:			3676954230463352713
#   	Decision vector:	[26.6683, -291.665, 269.661, 37.3551, 379.551, ... ]
#   	Fitness vector:		[443.291]
#   #30:
#   	ID:			3991290275743728752
#   	Decision vector:	[494.467, -210.383, 362.354, -30.0664, 306.954, ... ]
#   	Fitness vector:		[284.735]
#   #31:
#   	ID:			16981369922356100525
#   	Decision vector:	[187.091, -322.12, 439.519, 66.9534, 104.258, ... ]
#   	Fitness vector:		[376.193]
#   #32:
#   	ID:			9049504384480694738
#   	Decision vector:	[596.002, -450.271, 180.164, -83.2961, 53.8108, ... ]
#   	Fitness vector:		[248.104]
#   #33:
#   	ID:			15665871201088247711
#   	Decision vector:	[405.558, -390.881, -115.136, 183.71, 356.862, ... ]
#   	Fitness vector:		[375.888]
#   #34:
#   	ID:			8395429812993607298
#   	Decision vector:	[220.911, -479.853, 192.912, -216.516, 322.459, ... ]
#   	Fitness vector:		[315.459]
#   #35:
#   	ID:			17427233450009322150
#   	Decision vector:	[570.012, -522.368, 184.817, 15.9789, 298.76, ... ]
#   	Fitness vector:		[442.641]
#   #36:
#   	ID:			13397309235255809997
#   	Decision vector:	[445.448, -534.234, 300.399, -577.162, 557.086, ... ]
#   	Fitness vector:		[511.76]
#   #37:
#   	ID:			7514736503523423908
#   	Decision vector:	[540.088, -29.4688, 80.5951, 122.394, 516.736, ... ]
#   	Fitness vector:		[216.865]
#   #38:
#   	ID:			7744491533144990262
#   	Decision vector:	[366.793, -568.409, 260.795, 19.4381, 446.028, ... ]
#   	Fitness vector:		[394.28]
#   #39:
#   	ID:			11536841766837987056
#   	Decision vector:	[371.535, -574.673, -87.4385, 101.688, 385.198, ... ]
#   	Fitness vector:		[401.152]
#   #40:
#   	ID:			17240239183589772811
#   	Decision vector:	[586.543, -56.3841, 390.842, 19.0765, 77.0179, ... ]
#   	Fitness vector:		[395.508]
#   #41:
#   	ID:			9155702560218266538
#   	Decision vector:	[312.03, -485.282, 139.569, -22.8936, 374.998, ... ]
#   	Fitness vector:		[348.405]
#   #42:
#   	ID:			15884582255490642572
#   	Decision vector:	[461.873, -14.9109, 5.43682, 241.318, 287.907, ... ]
#   	Fitness vector:		[352.973]
#   #43:
#   	ID:			9802089293239498402
#   	Decision vector:	[20.8265, -124.84, 224.933, -70.5413, -51.0299, ... ]
#   	Fitness vector:		[569.444]
#   #44:
#   	ID:			1247796552286349558
#   	Decision vector:	[350.679, -539.259, 14.434, -10.841, 572.232, ... ]
#   	Fitness vector:		[250.175]
#   #45:
#   	ID:			2411011014636967255
#   	Decision vector:	[248.265, -98.0742, 184.653, -148.235, 300.003, ... ]
#   	Fitness vector:		[365.926]
#   #46:
#   	ID:			512830168174338560
#   	Decision vector:	[385.715, -339.313, 296.003, 234.089, 253.433, ... ]
#   	Fitness vector:		[351.026]
#   #47:
#   	ID:			12395682245797912363
#   	Decision vector:	[343.323, -31.1071, -223.48, -315.692, 565.059, ... ]
#   	Fitness vector:		[438.576]
#   #48:
#   	ID:			1043750935261532435
#   	Decision vector:	[397.886, -319.641, -32.6918, -108.853, 231.65, ... ]
#   	Fitness vector:		[319.115]
#   #49:
#   	ID:			15996207456514142779
#   	Decision vector:	[290.045, 211.213, 380.716, 134.568, 138.539, ... ]
#   	Fitness vector:		[455.48]
#   #50:
#   	ID:			7229535937762185213
#   	Decision vector:	[420.247, -411.998, -126.41, 104.184, 57.5446, ... ]
#   	Fitness vector:		[398.786]
#   #51:
#   	ID:			14043892262923552714
#   	Decision vector:	[401.248, -298.058, 115.313, 331.304, 520.283, ... ]
#   	Fitness vector:		[285.929]
#   #52:
#   	ID:			4094938435936059159
#   	Decision vector:	[279.497, -506.456, 249.81, 10.9118, 361.071, ... ]
#   	Fitness vector:		[572.371]
#   #53:
#   	ID:			1912221584581384952
#   	Decision vector:	[413.442, -368.784, -330.842, -46.0386, 493.564, ... ]
#   	Fitness vector:		[368.045]
#   #54:
#   	ID:			2701496665568203459
#   	Decision vector:	[474.056, -385.122, -29.9295, -112.59, 1.24726, ... ]
#   	Fitness vector:		[426.542]
#   #55:
#   	ID:			10784724986759222419
#   	Decision vector:	[453.106, -339.832, 489.49, -54.5683, 563.456, ... ]
#   	Fitness vector:		[279.757]
#   #56:
#   	ID:			11672797991117284350
#   	Decision vector:	[384.633, -342.117, 113.741, -29.9914, 518.066, ... ]
#   	Fitness vector:		[231.087]
#   #57:
#   	ID:			16449973265539317921
#   	Decision vector:	[529.839, -577.437, 38.9552, 191.031, 53.9481, ... ]
#   	Fitness vector:		[406.477]
#   #58:
#   	ID:			4310301120224420839
#   	Decision vector:	[144.917, -99.0001, 264.776, -202.193, 343.433, ... ]
#   	Fitness vector:		[368.713]
#   #59:
#   	ID:			11897016052137519835
#   	Decision vector:	[451.054, 58.7314, -184.477, 154.704, 278.063, ... ]
#   	Fitness vector:		[505.66]
#   #60:
#   	ID:			16283123593384966060
#   	Decision vector:	[516.07, -344.329, 216.288, -169.168, 275.133, ... ]
#   	Fitness vector:		[311.451]
#   #61:
#   	ID:			6041918823320825202
#   	Decision vector:	[445.624, -450.97, 32.3833, 101.02, 405.72, ... ]
#   	Fitness vector:		[563.77]
#   #62:
#   	ID:			13582905386853642257
#   	Decision vector:	[63.1333, -121.495, 123.522, -218.318, -9.80731, ... ]
#   	Fitness vector:		[344.285]
#   #63:
#   	ID:			13993795930535283000
#   	Decision vector:	[444.808, -331.297, -20.3118, -302.537, 144.443, ... ]
#   	Fitness vector:		[382.337]
#   #64:
#   	ID:			16443466038036687211
#   	Decision vector:	[481.293, -72.0829, 231.166, 149.374, 287.686, ... ]
#   	Fitness vector:		[554.911]
#   #65:
#   	ID:			15799160394448242879
#   	Decision vector:	[159.877, -370.551, -51.2859, -275.823, 333.492, ... ]
#   	Fitness vector:		[242.076]
#   #66:
#   	ID:			1502837664918511572
#   	Decision vector:	[394.351, -301.4, 254.091, -119.862, 392.319, ... ]
#   	Fitness vector:		[283.377]
#   #67:
#   	ID:			8701733356748298325
#   	Decision vector:	[498.771, -125.014, 151.019, -65.3401, 540.134, ... ]
#   	Fitness vector:		[371.209]
#   #68:
#   	ID:			14626185667690627571
#   	Decision vector:	[437.293, -448.91, -31.2596, -79.9647, 438.405, ... ]
#   	Fitness vector:		[530.834]
#   #69:
#   	ID:			13890480263780897966
#   	Decision vector:	[380.195, -230.662, 326.2, 132.401, 545.208, ... ]
#   	Fitness vector:		[290.095]
#   #70:
#   	ID:			13720150016270389834
#   	Decision vector:	[356.412, -443.81, 267.467, -112.919, 194.296, ... ]
#   	Fitness vector:		[323.606]
#   #71:
#   	ID:			104056975415421551
#   	Decision vector:	[-84.6491, -177.657, -594.581, 185.71, 575.424, ... ]
#   	Fitness vector:		[499.209]
#   #72:
#   	ID:			15959386665064133613
#   	Decision vector:	[509.289, -554.174, 24.1937, 317.695, 294.054, ... ]
#   	Fitness vector:		[465.873]
#   #73:
#   	ID:			4140779234101294551
#   	Decision vector:	[554.557, 115.635, -392.923, -518.624, 83.0725, ... ]
#   	Fitness vector:		[399.469]
#   #74:
#   	ID:			5780724163403000096
#   	Decision vector:	[399.703, -330.349, 382.876, -182.933, 127.893, ... ]
#   	Fitness vector:		[463.272]
#   #75:
#   	ID:			9869926242304591943
#   	Decision vector:	[304.645, 43.6962, -249.565, 110.995, 399.263, ... ]
#   	Fitness vector:		[303.924]
#   #76:
#   	ID:			13677810612207885889
#   	Decision vector:	[582.12, -399.828, 29.9714, 337.229, 548.882, ... ]
#   	Fitness vector:		[285.215]
#   #77:
#   	ID:			3663926790231072014
#   	Decision vector:	[367.939, -502.389, 221.903, 246.147, 469.946, ... ]
#   	Fitness vector:		[460.319]
#   #78:
#   	ID:			11748941366581064079
#   	Decision vector:	[312.852, -235.263, -25.3587, -106.151, 477.911, ... ]
#   	Fitness vector:		[635.981]
#   #79:
#   	ID:			1834885002265901748
#   	Decision vector:	[595.205, -104.698, -80.5686, -6.10782, 223.67, ... ]
#   	Fitness vector:		[474.277]
#   #80:
#   	ID:			5362772216456720486
#   	Decision vector:	[163.812, -269.808, 146.626, 115.392, 303.987, ... ]
#   	Fitness vector:		[359.349]
#   #81:
#   	ID:			1354448177322124209
#   	Decision vector:	[217.346, -282.983, 451.099, -277.353, -28.6135, ... ]
#   	Fitness vector:		[215.459]
#   #82:
#   	ID:			17623829949309168833
#   	Decision vector:	[576.549, -377.414, 80.3654, -365.898, 320.951, ... ]
#   	Fitness vector:		[324.788]
#   #83:
#   	ID:			5183649184466607690
#   	Decision vector:	[313.556, -157.255, 3.00126, -78.4122, 129.527, ... ]
#   	Fitness vector:		[366.42]
#   #84:
#   	ID:			3200411107488405488
#   	Decision vector:	[575.835, -325.916, 300.303, 146.268, 495.578, ... ]
#   	Fitness vector:		[369.87]
#   #85:
#   	ID:			7112655227198101231
#   	Decision vector:	[495.952, -159.801, -304.348, 169.869, 407.137, ... ]
#   	Fitness vector:		[307.915]
#   #86:
#   	ID:			1637449397291609376
#   	Decision vector:	[447.54, -481.841, -270.643, -120.156, 172.807, ... ]
#   	Fitness vector:		[402.768]
#   #87:
#   	ID:			15171478455142479384
#   	Decision vector:	[365.166, -404.1, 448.354, 581.411, -187.993, ... ]
#   	Fitness vector:		[548.157]
#   #88:
#   	ID:			10301090294912487902
#   	Decision vector:	[398.475, -228.064, 81.1489, 98.5263, 470.689, ... ]
#   	Fitness vector:		[392.731]
#   #89:
#   	ID:			6676980116969800596
#   	Decision vector:	[412.817, -463.953, -221.62, -496.006, 272.64, ... ]
#   	Fitness vector:		[411.086]
#   #90:
#   	ID:			8396422725058707169
#   	Decision vector:	[504.889, -111.595, 205.108, -82.6172, 449.001, ... ]
#   	Fitness vector:		[253.503]
#   #91:
#   	ID:			1859076449795172048
#   	Decision vector:	[81.7986, -232.847, 520.844, 207.358, 354.718, ... ]
#   	Fitness vector:		[432.371]
#   #92:
#   	ID:			16531750522682343483
#   	Decision vector:	[361.734, 101.945, 259.883, 24.3296, 594.562, ... ]
#   	Fitness vector:		[431.021]
#   #93:
#   	ID:			1348316913162031876
#   	Decision vector:	[39.8279, 83.8267, -62.3188, 217.616, 410.906, ... ]
#   	Fitness vector:		[452.793]
#   #94:
#   	ID:			6505260245021410976
#   	Decision vector:	[194.214, -187.618, 352.228, -86.228, 131.226, ... ]
#   	Fitness vector:		[456.962]
#   #95:
#   	ID:			1813999754814952482
#   	Decision vector:	[459.365, -378.627, -160.414, -238.794, 454.177, ... ]
#   	Fitness vector:		[384.129]
#   #96:
#   	ID:			12358421756577092511
#   	Decision vector:	[512.037, -164.645, 181.771, 419.377, 276.11, ... ]
#   	Fitness vector:		[490.868]
#   #97:
#   	ID:			7962062347785663431
#   	Decision vector:	[524.702, -241.315, 29.3141, 73.5298, 406.533, ... ]
#   	Fitness vector:		[520.655]
#   #98:
#   	ID:			12922584347166259754
#   	Decision vector:	[70.6959, -281.059, -118.87, 0.877618, 96.1773, ... ]
#   	Fitness vector:		[367.17]
#   #99:
#   	ID:			6264273121927259993
#   	Decision vector:	[486.624, 71.3423, 332.805, 95.2245, 410.735, ... ]
#   	Fitness vector:		[405.121]
#
#   Champion decision vector: [217.346, -282.983, 451.099, -277.353, -28.6135, ... ]
#   Champion fitness: [215.459],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			50
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 20100
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 50
#   Population size: 100
#
#   List of individuals:
#   #0:
#   	ID:			2225206138463043340
#   	Decision vector:	[510.451, -195.302, 147.979, -84.1525, 506.179, ... ]
#   	Fitness vector:		[78.074]
#   #1:
#   	ID:			12297052430986820814
#   	Decision vector:	[417.75, -317.662, 153.141, -14.9173, 502.4, ... ]
#   	Fitness vector:		[-3.90598]
#   #2:
#   	ID:			5285667643970941218
#   	Decision vector:	[591.119, -248.317, 60.8967, -44.9114, 457.888, ... ]
#   	Fitness vector:		[33.5248]
#   #3:
#   	ID:			18374549529275722835
#   	Decision vector:	[380.356, -268.218, 55.4026, 54.7106, 329.519, ... ]
#   	Fitness vector:		[33.8818]
#   #4:
#   	ID:			3523456383179486427
#   	Decision vector:	[398.364, -427.004, 59.0927, -296.054, 210.026, ... ]
#   	Fitness vector:		[68.6555]
#   #5:
#   	ID:			16143198337935166698
#   	Decision vector:	[546.467, -460.206, 246.497, -120.767, 274.101, ... ]
#   	Fitness vector:		[59.6493]
#   #6:
#   	ID:			2679642930772534122
#   	Decision vector:	[397.895, -284.81, 282.573, -258.448, 228.357, ... ]
#   	Fitness vector:		[81.7714]
#   #7:
#   	ID:			8926177331335096686
#   	Decision vector:	[350.324, -373.352, 193.768, -42.9375, 469.851, ... ]
#   	Fitness vector:		[-16.7232]
#   #8:
#   	ID:			13085856269157907389
#   	Decision vector:	[554.598, -294.485, 421.244, -50.4767, 484.522, ... ]
#   	Fitness vector:		[25.1634]
#   #9:
#   	ID:			9548467525468391450
#   	Decision vector:	[435.13, -351.991, 157.605, 16.3342, 458.879, ... ]
#   	Fitness vector:		[50.216]
#   #10:
#   	ID:			11943021808861229888
#   	Decision vector:	[528.289, 17.5986, 57.1968, -132.57, 399.379, ... ]
#   	Fitness vector:		[122.294]
#   #11:
#   	ID:			3542330960622651304
#   	Decision vector:	[479.108, -271.943, 138.143, -274.335, 528.837, ... ]
#   	Fitness vector:		[31.4824]
#   #12:
#   	ID:			4202206382085644130
#   	Decision vector:	[439.067, -585.218, 133.144, 94.03, 309.119, ... ]
#   	Fitness vector:		[143.791]
#   #13:
#   	ID:			3184124607595428052
#   	Decision vector:	[441.336, -456.208, 181.289, 46.6379, 484.397, ... ]
#   	Fitness vector:		[-19.6299]
#   #14:
#   	ID:			13936042818324245572
#   	Decision vector:	[522.758, -331.622, -71.1719, -8.58596, 374.252, ... ]
#   	Fitness vector:		[72.5204]
#   #15:
#   	ID:			8949426634201417972
#   	Decision vector:	[547.9, -250.37, -56.7694, -51.8391, 471.558, ... ]
#   	Fitness vector:		[59.673]
#   #16:
#   	ID:			12078054439952405508
#   	Decision vector:	[456.133, -387.888, -77.9989, -19.3294, 260.055, ... ]
#   	Fitness vector:		[-6.33055]
#   #17:
#   	ID:			13894167959374236419
#   	Decision vector:	[383.38, -367.071, 187.746, -139.204, 394.296, ... ]
#   	Fitness vector:		[106.776]
#   #18:
#   	ID:			8362760210316625397
#   	Decision vector:	[550.768, -348.971, 143.306, -235.458, 407.496, ... ]
#   	Fitness vector:		[53.8178]
#   #19:
#   	ID:			7196541724872274580
#   	Decision vector:	[360.771, -377.358, 275.932, -113.075, 464.581, ... ]
#   	Fitness vector:		[99.6283]
#   #20:
#   	ID:			1550932363424780449
#   	Decision vector:	[542.2, -284.127, -2.94364, 156.203, 482.648, ... ]
#   	Fitness vector:		[65.6951]
#   #21:
#   	ID:			6888248217719895857
#   	Decision vector:	[336.614, -366.41, 158.151, -15.6122, 597.841, ... ]
#   	Fitness vector:		[66.527]
#   #22:
#   	ID:			12663017763644598570
#   	Decision vector:	[353.562, -306.119, 130.143, -17.1073, 512.794, ... ]
#   	Fitness vector:		[12.1172]
#   #23:
#   	ID:			8578079531890885389
#   	Decision vector:	[529.986, -196.91, 75.8787, -168.586, 341.664, ... ]
#   	Fitness vector:		[14.3991]
#   #24:
#   	ID:			13940206447630858189
#   	Decision vector:	[401.448, -298.852, -95.2033, 38.9235, 408.637, ... ]
#   	Fitness vector:		[85.1453]
#   #25:
#   	ID:			1086177176438975582
#   	Decision vector:	[577.474, -286.791, 148.986, -140.327, 217.315, ... ]
#   	Fitness vector:		[15.0289]
#   #26:
#   	ID:			10883301874930944361
#   	Decision vector:	[444.95, -553.865, 12.822, -214.068, 540.259, ... ]
#   	Fitness vector:		[46.6619]
#   #27:
#   	ID:			15960943583987012692
#   	Decision vector:	[421.448, -154.535, 82.6209, -106.132, 508.406, ... ]
#   	Fitness vector:		[100.789]
#   #28:
#   	ID:			10406297328975478953
#   	Decision vector:	[453.614, -381.14, 8.99957, -26.5432, 456.907, ... ]
#   	Fitness vector:		[52.5032]
#   #29:
#   	ID:			3676954230463352713
#   	Decision vector:	[481.295, -267.328, 345.47, -226.164, 286.73, ... ]
#   	Fitness vector:		[63.9579]
#   #30:
#   	ID:			3991290275743728752
#   	Decision vector:	[433.398, -450.176, -122.822, 60.2077, 336.557, ... ]
#   	Fitness vector:		[37.8499]
#   #31:
#   	ID:			16981369922356100525
#   	Decision vector:	[560.835, -214.698, -80.0025, 48.824, 597.221, ... ]
#   	Fitness vector:		[-14.2459]
#   #32:
#   	ID:			9049504384480694738
#   	Decision vector:	[453.428, -152.187, -108.371, 117.997, 357.498, ... ]
#   	Fitness vector:		[27.4491]
#   #33:
#   	ID:			15665871201088247711
#   	Decision vector:	[444.464, -552.633, 341.163, -68.9725, 561.194, ... ]
#   	Fitness vector:		[11.2925]
#   #34:
#   	ID:			8395429812993607298
#   	Decision vector:	[456.427, -430.987, -45.2561, 33.1466, 374.141, ... ]
#   	Fitness vector:		[8.35479]
#   #35:
#   	ID:			17427233450009322150
#   	Decision vector:	[385.556, -164.459, 328.149, 59.3413, 366.146, ... ]
#   	Fitness vector:		[20.9561]
#   #36:
#   	ID:			13397309235255809997
#   	Decision vector:	[337.57, -465.45, 81.7901, -173.392, 365.008, ... ]
#   	Fitness vector:		[92.0704]
#   #37:
#   	ID:			7514736503523423908
#   	Decision vector:	[540.088, -252.93, -66.8095, 20.2223, 322.074, ... ]
#   	Fitness vector:		[30.985]
#   #38:
#   	ID:			7744491533144990262
#   	Decision vector:	[490.648, -301.363, 20.0865, 84.4281, 459.587, ... ]
#   	Fitness vector:		[29.0968]
#   #39:
#   	ID:			11536841766837987056
#   	Decision vector:	[359.185, -502.799, 226.543, -62.8791, 420.202, ... ]
#   	Fitness vector:		[107.542]
#   #40:
#   	ID:			17240239183589772811
#   	Decision vector:	[592.436, -197.703, 193.87, -50.2364, 505.118, ... ]
#   	Fitness vector:		[31.209]
#   #41:
#   	ID:			9155702560218266538
#   	Decision vector:	[599.839, -8.28896, 57.3119, 252.407, 348.069, ... ]
#   	Fitness vector:		[115.713]
#   #42:
#   	ID:			15884582255490642572
#   	Decision vector:	[370.965, -454.561, 187.536, -1.76237, 318.058, ... ]
#   	Fitness vector:		[7.40043]
#   #43:
#   	ID:			9802089293239498402
#   	Decision vector:	[574.097, -279.856, 110.344, -129.374, 423.874, ... ]
#   	Fitness vector:		[57.4779]
#   #44:
#   	ID:			1247796552286349558
#   	Decision vector:	[447.366, -412.566, 161.74, 160.82, 106.592, ... ]
#   	Fitness vector:		[28.7072]
#   #45:
#   	ID:			2411011014636967255
#   	Decision vector:	[182.538, -278.475, 88.4225, -105.053, 313.255, ... ]
#   	Fitness vector:		[88.6217]
#   #46:
#   	ID:			512830168174338560
#   	Decision vector:	[495.115, -356.151, 249.867, 149.081, 341.799, ... ]
#   	Fitness vector:		[17.3123]
#   #47:
#   	ID:			12395682245797912363
#   	Decision vector:	[515.067, -464.75, 177.933, 82.9078, 567.014, ... ]
#   	Fitness vector:		[46.915]
#   #48:
#   	ID:			1043750935261532435
#   	Decision vector:	[548.204, -529.612, -32.6918, -108.853, 414.615, ... ]
#   	Fitness vector:		[2.57751]
#   #49:
#   	ID:			15996207456514142779
#   	Decision vector:	[511.476, -318.529, 190.914, -18.2495, 472.186, ... ]
#   	Fitness vector:		[41.8918]
#   #50:
#   	ID:			7229535937762185213
#   	Decision vector:	[420.247, -411.998, 285.06, -176.184, 498.759, ... ]
#   	Fitness vector:		[20.087]
#   #51:
#   	ID:			14043892262923552714
#   	Decision vector:	[492.503, -304.108, 193.511, -247.233, 462.755, ... ]
#   	Fitness vector:		[-1.99272]
#   #52:
#   	ID:			4094938435936059159
#   	Decision vector:	[550.388, -400.54, 17.934, 273.49, 521.54, ... ]
#   	Fitness vector:		[80.5901]
#   #53:
#   	ID:			1912221584581384952
#   	Decision vector:	[404.008, -130.186, 355.113, -318.398, 344.677, ... ]
#   	Fitness vector:		[99.8582]
#   #54:
#   	ID:			2701496665568203459
#   	Decision vector:	[483.233, -470.094, -32.1236, -341.108, 176.738, ... ]
#   	Fitness vector:		[57.6196]
#   #55:
#   	ID:			10784724986759222419
#   	Decision vector:	[581.302, -99.0219, 72.8461, 73.8744, 495.151, ... ]
#   	Fitness vector:		[56.5617]
#   #56:
#   	ID:			11672797991117284350
#   	Decision vector:	[544.791, -162.06, 148.243, -186.023, 520.237, ... ]
#   	Fitness vector:		[24.4434]
#   #57:
#   	ID:			16449973265539317921
#   	Decision vector:	[156.543, -218.919, 333.514, -142.459, 560.178, ... ]
#   	Fitness vector:		[64.7673]
#   #58:
#   	ID:			4310301120224420839
#   	Decision vector:	[439.714, -479.925, 359.688, -161.622, 440.08, ... ]
#   	Fitness vector:		[29.0256]
#   #59:
#   	ID:			11897016052137519835
#   	Decision vector:	[403.144, -270.837, 154.572, 89.6501, 562.914, ... ]
#   	Fitness vector:		[35.1211]
#   #60:
#   	ID:			16283123593384966060
#   	Decision vector:	[516.07, -344.329, 216.288, -169.168, 275.133, ... ]
#   	Fitness vector:		[3.26254]
#   #61:
#   	ID:			6041918823320825202
#   	Decision vector:	[445.624, -450.97, 32.3833, 101.02, 405.72, ... ]
#   	Fitness vector:		[41.9467]
#   #62:
#   	ID:			13582905386853642257
#   	Decision vector:	[508.906, -141.369, 0.217047, -42.8326, 513.073, ... ]
#   	Fitness vector:		[70.7773]
#   #63:
#   	ID:			13993795930535283000
#   	Decision vector:	[444.808, -331.297, -20.3118, 182.481, 382.366, ... ]
#   	Fitness vector:		[-8.12508]
#   #64:
#   	ID:			16443466038036687211
#   	Decision vector:	[482.954, -206.037, 11.8108, 59.6076, 543.837, ... ]
#   	Fitness vector:		[-28.3909]
#   #65:
#   	ID:			15799160394448242879
#   	Decision vector:	[411.366, -307.138, 77.3848, -275.823, 333.492, ... ]
#   	Fitness vector:		[-17.9153]
#   #66:
#   	ID:			1502837664918511572
#   	Decision vector:	[394.351, -301.4, 254.091, -215.762, 499.712, ... ]
#   	Fitness vector:		[77.1968]
#   #67:
#   	ID:			8701733356748298325
#   	Decision vector:	[435.364, -274.794, -14.2567, 273.766, 578.137, ... ]
#   	Fitness vector:		[-30.1546]
#   #68:
#   	ID:			14626185667690627571
#   	Decision vector:	[547.203, -364.216, 146.521, -178.857, 444.058, ... ]
#   	Fitness vector:		[50.2223]
#   #69:
#   	ID:			13890480263780897966
#   	Decision vector:	[382.904, -230.662, 326.2, 132.401, 545.208, ... ]
#   	Fitness vector:		[44.6342]
#   #70:
#   	ID:			13720150016270389834
#   	Decision vector:	[356.412, -443.81, 267.467, 14.8714, 245.89, ... ]
#   	Fitness vector:		[40.3474]
#   #71:
#   	ID:			104056975415421551
#   	Decision vector:	[495.915, -347.922, 219.297, -255.831, 580.378, ... ]
#   	Fitness vector:		[35.8065]
#   #72:
#   	ID:			15959386665064133613
#   	Decision vector:	[331.574, -424.506, 1.85342, -39.0543, 585.599, ... ]
#   	Fitness vector:		[55.4949]
#   #73:
#   	ID:			4140779234101294551
#   	Decision vector:	[568.891, -371.962, 124.135, -211.278, 329.293, ... ]
#   	Fitness vector:		[24.0982]
#   #74:
#   	ID:			5780724163403000096
#   	Decision vector:	[424.899, -75.562, 15.7894, 130.034, 423.211, ... ]
#   	Fitness vector:		[10.1009]
#   #75:
#   	ID:			9869926242304591943
#   	Decision vector:	[588.459, -437.069, 193.096, 93.3783, 480.103, ... ]
#   	Fitness vector:		[103.453]
#   #76:
#   	ID:			13677810612207885889
#   	Decision vector:	[582.12, -449.114, 238.888, 85.5668, 390.802, ... ]
#   	Fitness vector:		[3.75144]
#   #77:
#   	ID:			3663926790231072014
#   	Decision vector:	[367.939, -502.389, 221.903, 104.032, 552.953, ... ]
#   	Fitness vector:		[-4.02383]
#   #78:
#   	ID:			11748941366581064079
#   	Decision vector:	[571.012, -335.497, 31.5637, -63.9602, 538.15, ... ]
#   	Fitness vector:		[92.4341]
#   #79:
#   	ID:			1834885002265901748
#   	Decision vector:	[352.337, -448.994, -52.6963, 203.998, 373.783, ... ]
#   	Fitness vector:		[71.7965]
#   #80:
#   	ID:			5362772216456720486
#   	Decision vector:	[486.204, -300.729, 28.9388, 201.323, 362.784, ... ]
#   	Fitness vector:		[55.2182]
#   #81:
#   	ID:			1354448177322124209
#   	Decision vector:	[540.135, -135.264, 150.808, 230.17, 549.771, ... ]
#   	Fitness vector:		[29.4671]
#   #82:
#   	ID:			17623829949309168833
#   	Decision vector:	[506.746, -377.414, 80.3654, 140.812, 499.875, ... ]
#   	Fitness vector:		[25.9991]
#   #83:
#   	ID:			5183649184466607690
#   	Decision vector:	[466.873, -347.458, 25.3529, -157.987, 484.367, ... ]
#   	Fitness vector:		[91.691]
#   #84:
#   	ID:			3200411107488405488
#   	Decision vector:	[320.882, -364.54, 354.436, -81.1715, 455.398, ... ]
#   	Fitness vector:		[1.72374]
#   #85:
#   	ID:			7112655227198101231
#   	Decision vector:	[554.77, -94.2162, -76.3875, 169.869, 407.137, ... ]
#   	Fitness vector:		[17.3543]
#   #86:
#   	ID:			1637449397291609376
#   	Decision vector:	[319.892, -374.323, 272.764, -120.156, 172.807, ... ]
#   	Fitness vector:		[32.8943]
#   #87:
#   	ID:			15171478455142479384
#   	Decision vector:	[579.559, -218.581, 131.526, -178.004, 333.482, ... ]
#   	Fitness vector:		[10.2346]
#   #88:
#   	ID:			10301090294912487902
#   	Decision vector:	[452.024, -223.049, 256.155, -98.1119, 494.979, ... ]
#   	Fitness vector:		[111.428]
#   #89:
#   	ID:			6676980116969800596
#   	Decision vector:	[432.358, -150.503, -34.6958, -13.965, 333.35, ... ]
#   	Fitness vector:		[84.2298]
#   #90:
#   	ID:			8396422725058707169
#   	Decision vector:	[504.889, -111.595, 187.159, -82.6172, 449.001, ... ]
#   	Fitness vector:		[-15.6183]
#   #91:
#   	ID:			1859076449795172048
#   	Decision vector:	[310.85, -495.923, -73.2166, 34.486, 322.19, ... ]
#   	Fitness vector:		[69.8519]
#   #92:
# ...
#   	Fitness vector:		[-180]
#   #90:
#   	ID:			8396422725058707169
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8201, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #91:
#   	ID:			1859076449795172048
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8211, 469.56, ... ]
#   	Fitness vector:		[-180]
#   #92:
#   	ID:			16531750522682343483
#   	Decision vector:	[540.155, -322.634, 128.211, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #93:
#   	ID:			1348316913162031876
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8213, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #94:
#   	ID:			6505260245021410976
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #95:
#   	ID:			1813999754814952482
#   	Decision vector:	[540.156, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #96:
#   	ID:			12358421756577092511
#   	Decision vector:	[540.155, -322.635, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #97:
#   	ID:			7962062347785663431
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #98:
#   	ID:			12922584347166259754
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8205, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #99:
#   	ID:			6264273121927259993
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#
#   Champion decision vector: [540.155, -322.633, 128.212, -16.821, 469.559, ... ]
#   Champion fitness: [-180],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			50
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 328600
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 50
#   Population size: 100
#
#   List of individuals:
#   #0:
#   	ID:			2225206138463043340
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #1:
#   	ID:			12297052430986820814
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8205, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #2:
#   	ID:			5285667643970941218
#   	Decision vector:	[540.155, -322.634, 128.211, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #3:
#   	ID:			18374549529275722835
#   	Decision vector:	[540.155, -322.633, 128.212, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #4:
#   	ID:			3523456383179486427
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #5:
#   	ID:			16143198337935166698
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8204, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #6:
#   	ID:			2679642930772534122
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8213, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #7:
#   	ID:			8926177331335096686
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8208, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #8:
#   	ID:			13085856269157907389
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8214, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #9:
#   	ID:			9548467525468391450
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8216, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #10:
#   	ID:			11943021808861229888
#   	Decision vector:	[540.156, -322.634, 128.211, -16.8205, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #11:
#   	ID:			3542330960622651304
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8215, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #12:
#   	ID:			4202206382085644130
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8211, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #13:
#   	ID:			3184124607595428052
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #14:
#   	ID:			13936042818324245572
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #15:
#   	ID:			8949426634201417972
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #16:
#   	ID:			12078054439952405508
#   	Decision vector:	[540.155, -322.633, 128.212, -16.8208, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #17:
#   	ID:			13894167959374236419
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #18:
#   	ID:			8362760210316625397
#   	Decision vector:	[540.155, -322.633, 128.211, -16.821, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #19:
#   	ID:			7196541724872274580
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8204, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #20:
#   	ID:			1550932363424780449
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8211, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #21:
#   	ID:			6888248217719895857
#   	Decision vector:	[540.155, -322.634, 128.211, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #22:
#   	ID:			12663017763644598570
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #23:
#   	ID:			8578079531890885389
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #24:
#   	ID:			13940206447630858189
#   	Decision vector:	[540.155, -322.633, 128.211, -16.821, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #25:
#   	ID:			1086177176438975582
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8203, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #26:
#   	ID:			10883301874930944361
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8211, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #27:
#   	ID:			15960943583987012692
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #28:
#   	ID:			10406297328975478953
#   	Decision vector:	[540.156, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #29:
#   	ID:			3676954230463352713
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #30:
#   	ID:			3991290275743728752
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #31:
#   	ID:			16981369922356100525
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8209, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #32:
#   	ID:			9049504384480694738
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8213, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #33:
#   	ID:			15665871201088247711
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #34:
#   	ID:			8395429812993607298
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8208, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #35:
#   	ID:			17427233450009322150
#   	Decision vector:	[540.155, -322.634, 128.211, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #36:
#   	ID:			13397309235255809997
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8213, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #37:
#   	ID:			7514736503523423908
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #38:
#   	ID:			7744491533144990262
#   	Decision vector:	[540.155, -322.633, 128.212, -16.8211, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #39:
#   	ID:			11536841766837987056
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8206, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #40:
#   	ID:			17240239183589772811
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8205, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #41:
#   	ID:			9155702560218266538
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8213, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #42:
#   	ID:			15884582255490642572
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8211, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #43:
#   	ID:			9802089293239498402
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8217, 469.56, ... ]
#   	Fitness vector:		[-180]
#   #44:
#   	ID:			1247796552286349558
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8217, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #45:
#   	ID:			2411011014636967255
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8216, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #46:
#   	ID:			512830168174338560
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #47:
#   	ID:			12395682245797912363
#   	Decision vector:	[540.155, -322.634, 128.211, -16.821, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #48:
#   	ID:			1043750935261532435
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #49:
#   	ID:			15996207456514142779
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8204, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #50:
#   	ID:			7229535937762185213
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8206, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #51:
#   	ID:			14043892262923552714
#   	Decision vector:	[540.155, -322.634, 128.21, -16.8209, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #52:
#   	ID:			4094938435936059159
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #53:
#   	ID:			1912221584581384952
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #54:
#   	ID:			2701496665568203459
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8213, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #55:
#   	ID:			10784724986759222419
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8202, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #56:
#   	ID:			11672797991117284350
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #57:
#   	ID:			16449973265539317921
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8208, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #58:
#   	ID:			4310301120224420839
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8206, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #59:
#   	ID:			11897016052137519835
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #60:
#   	ID:			16283123593384966060
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #61:
#   	ID:			6041918823320825202
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #62:
#   	ID:			13582905386853642257
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8217, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #63:
#   	ID:			13993795930535283000
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #64:
#   	ID:			16443466038036687211
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #65:
#   	ID:			15799160394448242879
#   	Decision vector:	[540.156, -322.634, 128.211, -16.8212, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #66:
#   	ID:			1502837664918511572
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #67:
#   	ID:			8701733356748298325
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8213, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #68:
#   	ID:			14626185667690627571
#   	Decision vector:	[540.155, -322.634, 128.212, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #69:
#   	ID:			13890480263780897966
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #70:
#   	ID:			13720150016270389834
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8209, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #71:
#   	ID:			104056975415421551
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8215, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #72:
#   	ID:			15959386665064133613
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #73:
#   	ID:			4140779234101294551
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #74:
#   	ID:			5780724163403000096
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8215, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #75:
#   	ID:			9869926242304591943
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8211, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #76:
#   	ID:			13677810612207885889
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #77:
#   	ID:			3663926790231072014
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8208, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #78:
#   	ID:			11748941366581064079
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8213, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #79:
#   	ID:			1834885002265901748
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8213, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #80:
#   	ID:			5362772216456720486
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8205, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #81:
#   	ID:			1354448177322124209
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #82:
#   	ID:			17623829949309168833
#   	Decision vector:	[540.155, -322.634, 128.212, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #83:
#   	ID:			5183649184466607690
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8203, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #84:
#   	ID:			3200411107488405488
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8203, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #85:
#   	ID:			7112655227198101231
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8215, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #86:
#   	ID:			1637449397291609376
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8213, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #87:
#   	ID:			15171478455142479384
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8206, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #88:
#   	ID:			10301090294912487902
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8204, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #89:
#   	ID:			6676980116969800596
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #90:
#   	ID:			8396422725058707169
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8201, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #91:
#   	ID:			1859076449795172048
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8211, 469.56, ... ]
#   	Fitness vector:		[-180]
#   #92:
#   	ID:			16531750522682343483
#   	Decision vector:	[540.155, -322.634, 128.211, -16.821, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #93:
#   	ID:			1348316913162031876
#   	Decision vector:	[540.155, -322.633, 128.211, -16.8213, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #94:
#   	ID:			6505260245021410976
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #95:
#   	ID:			1813999754814952482
#   	Decision vector:	[540.156, -322.634, 128.211, -16.8209, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #96:
#   	ID:			12358421756577092511
#   	Decision vector:	[540.155, -322.635, 128.211, -16.8207, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #97:
#   	ID:			7962062347785663431
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8212, 469.559, ... ]
#   	Fitness vector:		[-180]
#   #98:
#   	ID:			12922584347166259754
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8205, 469.558, ... ]
#   	Fitness vector:		[-180]
#   #99:
#   	ID:			6264273121927259993
#   	Decision vector:	[540.155, -322.634, 128.211, -16.8214, 469.559, ... ]
#   	Fitness vector:		[-180]
#
#   Champion decision vector: [540.155, -322.633, 128.212, -16.821, 469.559, ... ]
#   Champion fitness: [-180]])

# %%
x_val = [x[2] for x in test1[0]]
y_val = [x[1] for x in test1[0]]
plt.plot(x_val,y_val)
plt.xlabel('Time in seconds', fontsize=12)
plt.ylabel('Fitness', fontsize=12)
plt.title('Shifted Greiwank Function D = 50 using Differential Evolution', fontsize=13)
plt.show()

# %%
test2 = calc_fitness(100,aglo_differential_evolution_fn(80),SGrei_500,50)

# %%
test2
# Out:
# ([(0, array([25371.83992709]), 0.11967992782592773),
#   (1, array([19347.94989368]), 9.463706254959106),
#   (2, array([15970.19961141]), 19.07202386856079),
#   (3, array([13504.02838004]), 30.105534315109253),
#   (4, array([11580.28468735]), 42.0186927318573),
#   (5, array([10437.1897824]), 54.536235332489014),
#   (6, array([8918.37915133]), 68.5457911491394),
#   (7, array([8088.36147622]), 83.27157187461853),
#   (8, array([7404.66728392]), 98.32535314559937),
#   (9, array([6393.78330844]), 111.27884697914124),
#   (10, array([6069.02235431]), 123.4263391494751),
#   (11, array([5433.03906341]), 136.49441123008728),
#   (12, array([5002.18592841]), 148.6509189605713),
#   (13, array([4362.88888601]), 161.2147147655487),
#   (14, array([3941.42879583]), 175.26983213424683),
#   (15, array([3783.53194288]), 190.84320831298828),
#   (16, array([3627.93923712]), 208.70746064186096),
#   (17, array([3324.90038394]), 227.68274331092834),
#   (18, array([3048.37885357]), 244.2191596031189),
#   (19, array([2735.94151783]), 258.89493465423584),
#   (20, array([2519.90484554]), 273.21765184402466),
#   (21, array([2341.68209394]), 286.83026790618896),
#   (22, array([2172.15508582]), 299.80459094047546),
#   (23, array([2080.61224098]), 313.46707367897034),
#   (24, array([1952.78894541]), 327.99225068092346),
#   (25, array([1734.10989756]), 344.9399526119232),
#   (26, array([1632.95281614]), 364.3874845504761),
#   (27, array([1493.55632187]), 386.6898739337921),
#   (28, array([1342.56753539]), 405.9942762851715),
#   (29, array([1288.9537038]), 420.99219012260437),
#   (30, array([1164.30855206]), 435.03864645957947),
#   (31, array([1099.32673447]), 448.4916887283325),
#   (32, array([1008.79449745]), 462.7964549064636),
#   (33, array([882.09809432]), 478.7737503051758),
#   (34, array([850.80323154]), 495.9209203720093),
#   (35, array([781.31952484]), 518.2781655788422),
#   (36, array([712.99232545]), 538.9828243255615),
#   (37, array([667.95903831]), 555.4887082576752),
#   (38, array([600.4538767]), 570.3051059246063),
#   (39, array([571.63097342]), 584.6417860984802),
#   (40, array([529.02562886]), 598.2783381938934),
#   (41, array([476.92571079]), 612.4295148849487),
#   (42, array([420.44390215]), 627.5102074146271),
#   (43, array([397.03706622]), 643.5692851543427),
#   (44, array([353.29889676]), 667.2192721366882),
#   (45, array([323.69082797]), 686.5476086139679),
#   (46, array([284.73441543]), 701.4826898574829),
#   (47, array([264.43235232]), 715.0633909702301),
#   (48, array([237.42857165]), 728.5473506450653),
#   (49, array([205.84327096]), 740.7218105792999),
#   (50, array([185.89604235]), 752.6868312358856),
#   (51, array([157.83427623]), 765.3559679985046),
#   (52, array([139.8713771]), 778.8878009319305),
#   (53, array([109.30241874]), 793.7261419296265),
#   (54, array([90.4945047]), 810.0505080223083),
#   (55, array([71.84677741]), 830.0849614143372),
#   (56, array([48.65074798]), 847.3188977241516),
#   (57, array([34.44051523]), 862.4644165039062),
#   (58, array([22.22225839]), 875.8765683174133),
#   (59, array([9.48383448]), 888.8568742275238),
#   (60, array([3.51937654]), 900.8887150287628),
#   (61, array([-4.39519746]), 913.1479494571686),
#   (62, array([-15.705691]), 926.5002613067627),
#   (63, array([-29.76816976]), 940.6324887275696),
#   (64, array([-38.69484003]), 955.9116506576538),
#   (65, array([-46.54055434]), 974.3633337020874),
#   (66, array([-50.15828373]), 994.0387439727783),
#   (67, array([-59.79742288]), 1010.019031047821),
#   (68, array([-70.29824701]), 1023.8281226158142),
#   (69, array([-71.53155804]), 1037.0517783164978),
#   (70, array([-81.61508547]), 1049.513470172882),
#   (71, array([-85.51293709]), 1061.940256357193),
#   (72, array([-91.86964968]), 1074.5076653957367),
#   (73, array([-98.41172835]), 1087.915828704834),
#   (74, array([-104.83301049]), 1102.590606212616),
#   (75, array([-108.09326227]), 1119.8853816986084),
#   (76, array([-110.67534949]), 1138.683138847351),
#   (77, array([-117.13278431]), 1154.1148920059204),
#   (78, array([-120.85700322]), 1168.2261748313904),
#   (79, array([-125.67151997]), 1181.9125938415527),
#   (80, array([-127.8714094]), 1195.2260105609894),
#   (81, array([-132.38614165]), 1211.0477216243744),
#   (82, array([-135.13257197]), 1228.3224766254425),
#   (83, array([-137.61882004]), 1248.9054913520813),
#   (84, array([-139.0164038]), 1272.4893171787262),
#   (85, array([-142.54906001]), 1291.3207788467407),
#   (86, array([-144.99892292]), 1306.8364233970642),
#   (87, array([-146.96349358]), 1321.4770567417145),
#   (88, array([-149.11612104]), 1336.0729961395264),
#   (89, array([-151.39967997]), 1351.8424553871155),
#   (90, array([-153.89964294]), 1372.058028936386),
#   (91, array([-155.74021164]), 1402.126455783844),
#   (92, array([-156.22737268]), 1423.1722884178162),
#   (93, array([-157.43450354]), 1439.004641532898),
#   (94, array([-158.69049176]), 1453.9079999923706),
#   (95, array([-160.06303676]), 1468.9427933692932),
#   (96, array([-160.90390866]), 1484.2476255893707),
#   (97, array([-163.03009214]), 1500.6040253639221),
#   (98, array([-163.71580738]), 1523.010942697525),
#   (99, array([-164.66169317]), 1540.258683681488)],
#  [Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 50
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[255.546, -85.8349, 229.062, 262.98, -10.6573, ... ]
#   	Fitness vector:		[26592.5]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[-472.758, 288.017, 359.483, 376.661, 583.289, ... ]
#   	Fitness vector:		[29666.2]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[187.831, 76.4725, -588.277, -334.185, -361.996, ... ]
#   	Fitness vector:		[30168.9]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[67.6797, 355.939, 234.597, -534.638, 279.726, ... ]
#   	Fitness vector:		[30556.1]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[-203.996, -47.4359, 4.07059, -367.383, 107.957, ... ]
#   	Fitness vector:		[27428.4]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[575.356, 257.048, 574.199, 429.432, -129.513, ... ]
#   	Fitness vector:		[29506.3]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[-300.307, 141.93, -403.383, 451.054, 58.7314, ... ]
#   	Fitness vector:		[31996.9]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[-265.927, -574.72, -112.843, -460.815, -376.331, ... ]
#   	Fitness vector:		[32117.7]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[402.736, 296.093, 270.891, -93.4314, 245.931, ... ]
#   	Fitness vector:		[29832.7]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[563.572, 117.665, -114.23, 102.305, -144.907, ... ]
#   	Fitness vector:		[29466.1]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[424.104, 428.277, -323.988, -412, 258.073, ... ]
#   	Fitness vector:		[31870.6]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[-88.9854, -91.3667, -22.0489, -207.6, -72.6387, ... ]
#   	Fitness vector:		[29079]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[-357.659, 151.775, 144.536, -341.123, 269.001, ... ]
#   	Fitness vector:		[29302]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[-202.73, -116.922, 452.723, 25.7114, 110.759, ... ]
#   	Fitness vector:		[27669]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[213.441, -73.5961, 396.503, 232.892, -2.03956, ... ]
#   	Fitness vector:		[29019.7]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[-399.966, -18.0014, -6.91878, 350.265, 291.226, ... ]
#   	Fitness vector:		[26701.8]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[409.588, -176.73, 548.327, 450.974, -513.918, ... ]
#   	Fitness vector:		[30381.6]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[-283.138, 235.27, -153.124, -347.6, 340.271, ... ]
#   	Fitness vector:		[28438.1]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[284.966, 431.017, -380.201, -95.6267, 182.389, ... ]
#   	Fitness vector:		[28981.9]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[438.214, 269.714, 499.407, 263.17, 96.4967, ... ]
#   	Fitness vector:		[28889.7]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[-122.013, 443.679, -304.084, 494.419, 576.436, ... ]
#   	Fitness vector:		[30783.6]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[86.1545, -222.035, -136.236, -104.849, -447.169, ... ]
#   	Fitness vector:		[26436.9]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[-237.231, 214.082, 24.4998, -411.92, -358.123, ... ]
#   	Fitness vector:		[28341.9]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[-534.044, -85.0073, -119.403, 226.341, 307.801, ... ]
#   	Fitness vector:		[26794.9]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[468.975, 491.82, -297.472, -281.608, 39.005, ... ]
#   	Fitness vector:		[29468.2]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[22.257, -327.665, -503.64, -396.241, 283.497, ... ]
#   	Fitness vector:		[29213.1]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[475.154, -274.989, 567.187, -17.6629, -384.363, ... ]
#   	Fitness vector:		[31425]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[-460.905, -347.399, 17.5145, -147.474, -36.3221, ... ]
#   	Fitness vector:		[27714.9]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[185.269, 293.706, -560.704, -551.235, 438.423, ... ]
#   	Fitness vector:		[27659.4]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[23.8066, 114.488, -342.011, 47.2936, 470.066, ... ]
#   	Fitness vector:		[29737.2]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[-326.967, 336.376, 96.0422, 204.772, -398.147, ... ]
#   	Fitness vector:		[27479.4]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[-38.9817, -172.457, -69.8427, 230.736, -497.414, ... ]
#   	Fitness vector:		[29541.5]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[-285.489, -207.75, -244.605, 494.067, -29.4159, ... ]
#   	Fitness vector:		[27619.5]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[83.4503, -365.421, 174.452, -114.082, 102.848, ... ]
#   	Fitness vector:		[29047.2]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[-552.068, -160.805, -449.09, 347.234, -26.9767, ... ]
#   	Fitness vector:		[31235.5]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[-192.962, 69.9104, 528.125, 334.557, -566.401, ... ]
#   	Fitness vector:		[28886.8]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[-340.257, -534.037, 391.89, 443.653, -526.68, ... ]
#   	Fitness vector:		[28154.9]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[-301.682, 400.248, -494.301, -107.321, -384.762, ... ]
#   	Fitness vector:		[29635.2]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[318.902, -214.333, 147.624, -7.52306, -205.722, ... ]
#   	Fitness vector:		[28178.4]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[528.008, -477.07, 263.2, -417.727, 42.1506, ... ]
#   	Fitness vector:		[25371.8]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[-105.496, -450.496, -450.79, -363.051, 503.281, ... ]
#   	Fitness vector:		[27407.3]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[-181.944, 359.639, 380.574, -497.529, -4.10022, ... ]
#   	Fitness vector:		[29379.3]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[212.193, -231.333, 37.4941, -100.88, -165.512, ... ]
#   	Fitness vector:		[28505.1]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[331.908, -149.956, -216.187, -312.974, 356.959, ... ]
#   	Fitness vector:		[29139.4]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[-278.651, 322.759, 22.9777, 195.882, -364.448, ... ]
#   	Fitness vector:		[30384.7]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[25.6785, -126.521, -64.4403, 393.423, 9.94927, ... ]
#   	Fitness vector:		[28688.4]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[-134.243, -29.1166, -141.398, -542.552, 246.696, ... ]
#   	Fitness vector:		[28209.9]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[-597.366, 123.151, -193.547, 24.8455, 526.312, ... ]
#   	Fitness vector:		[28006.7]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[425.147, 309.627, -301.394, 511.161, -521.084, ... ]
#   	Fitness vector:		[30249.7]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[435.714, -117.92, 115.652, 316.452, -377.328, ... ]
#   	Fitness vector:		[30354.1]
#
#   Champion decision vector: [528.008, -477.07, 263.2, -417.727, 42.1506, ... ]
#   Champion fitness: [25371.8],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 4050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[255.546, -85.8349, 229.062, 262.98, -10.6573, ... ]
#   	Fitness vector:		[21039.9]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[-472.758, 288.017, 359.483, 376.661, 583.289, ... ]
#   	Fitness vector:		[22709.9]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[-26.326, 266.464, 119.698, -130.212, 508.721, ... ]
#   	Fitness vector:		[23147.9]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[344.828, -90.2991, 121.896, -206.627, 279.726, ... ]
#   	Fitness vector:		[23155.2]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[253.254, 307.644, 456.696, 191.794, 403.169, ... ]
#   	Fitness vector:		[22065.7]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[73.6623, -126.212, 450.256, 106.223, 419.595, ... ]
#   	Fitness vector:		[21151.1]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[586.532, 27.703, 10.6137, -336.097, -169.598, ... ]
#   	Fitness vector:		[24341]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[552.341, 25.1751, 175.62, 395.432, -506.045, ... ]
#   	Fitness vector:		[22628.3]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[402.736, 296.093, 270.891, -496.219, 167.934, ... ]
#   	Fitness vector:		[22361.1]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[563.572, 117.665, -114.23, 102.305, -144.907, ... ]
#   	Fitness vector:		[20854.8]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[-5.52529, -231.969, -278.873, -412, 258.073, ... ]
#   	Fitness vector:		[24384.6]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[-88.9854, -91.3667, -22.0489, -207.6, -300.613, ... ]
#   	Fitness vector:		[23926.8]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[224.596, 3.56793, -48.3495, -55.7544, 516.851, ... ]
#   	Fitness vector:		[21904.6]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[441.936, -435.231, 474.413, 190.779, 341.702, ... ]
#   	Fitness vector:		[20437.9]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[-61.7836, 155.688, 70.0716, -241.233, 456.008, ... ]
#   	Fitness vector:		[22266]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[310.798, -223.243, -448.787, -599.013, 227.253, ... ]
#   	Fitness vector:		[19347.9]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[586.187, 320.876, -263.03, -79.4306, 75.5104, ... ]
#   	Fitness vector:		[22989.6]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[-283.138, 235.27, -153.124, -347.6, 340.271, ... ]
#   	Fitness vector:		[21691.4]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[436.917, -282.651, 193.235, 174.683, -220.062, ... ]
#   	Fitness vector:		[22991.4]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[438.214, 269.714, 499.407, 263.17, 96.4967, ... ]
#   	Fitness vector:		[20565.4]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[-555.741, -139.354, 436.183, -363.54, -89.0368, ... ]
#   	Fitness vector:		[23307.8]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[86.1545, -222.035, -136.236, -104.849, -447.169, ... ]
#   	Fitness vector:		[21486.1]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[-237.231, 214.082, 372.326, -516.553, -250.209, ... ]
#   	Fitness vector:		[21883.3]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[-534.044, -85.0073, -119.403, 226.341, 307.801, ... ]
#   	Fitness vector:		[21798.4]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[321.324, 473.943, -6.64654, 161.334, -154.035, ... ]
#   	Fitness vector:		[21401.2]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[-222.139, -123.145, 338.699, -383.206, -246.874, ... ]
#   	Fitness vector:		[24051.9]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[475.154, -274.989, 404.914, 362.985, -304.658, ... ]
#   	Fitness vector:		[22950.4]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[386.244, -397.563, 549.005, -89.9804, -36.3221, ... ]
#   	Fitness vector:		[21190]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[185.269, -598.995, 255.495, 597.091, -253.964, ... ]
#   	Fitness vector:		[21361.8]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[23.8066, 114.488, -342.011, 47.2936, 470.066, ... ]
#   	Fitness vector:		[22637.6]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[-326.967, -133.324, 139.627, 86.027, 412.377, ... ]
#   	Fitness vector:		[21410]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[63.2258, -296.877, 92.2347, 124.585, 576.867, ... ]
#   	Fitness vector:		[22812.5]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[-285.489, -207.75, -244.605, 494.067, -29.4159, ... ]
#   	Fitness vector:		[22310.5]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[83.4503, -365.421, 174.452, -114.082, 102.848, ... ]
#   	Fitness vector:		[22166.6]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[284.365, 41.4327, 35.3851, -157.992, -319.536, ... ]
#   	Fitness vector:		[22019.6]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[-251.27, 98.4699, -157.207, -293.215, -1.4166, ... ]
#   	Fitness vector:		[21709.7]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[426.036, -424.073, 142.266, -177.758, -239.427, ... ]
#   	Fitness vector:		[20842.3]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[-301.682, 400.248, 212.934, -209.518, -384.762, ... ]
#   	Fitness vector:		[20190.2]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[444.822, -529.638, 266.341, -230.887, 230.098, ... ]
#   	Fitness vector:		[20503]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[276.435, 326.498, 239.201, 335.811, -204.932, ... ]
#   	Fitness vector:		[20241.7]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[-105.496, -450.496, 316.163, -202.415, -121.766, ... ]
#   	Fitness vector:		[21516.7]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[-304.595, 105.027, 470.6, -178.216, 190.479, ... ]
#   	Fitness vector:		[21720.3]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[346.596, -447.027, 201.62, -86.6687, 203.446, ... ]
#   	Fitness vector:		[21923.5]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[331.908, -149.956, -216.187, -312.974, 356.959, ... ]
#   	Fitness vector:		[21806]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[367.901, -457.437, -454.858, 93.5666, -364.448, ... ]
#   	Fitness vector:		[23999.4]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[453.313, 157.075, -123.704, 86.4492, -335.538, ... ]
#   	Fitness vector:		[22494.7]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[-48.05, -358.575, 312.3, 143.761, 472.925, ... ]
#   	Fitness vector:		[21156.9]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[-597.366, 123.151, -193.547, 24.8455, 526.312, ... ]
#   	Fitness vector:		[22321.5]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[427.974, 126.548, -301.394, 511.161, -521.084, ... ]
#   	Fitness vector:		[23380.6]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[435.714, -117.92, 115.652, 316.452, -454.729, ... ]
#   	Fitness vector:		[22461.2]
#
#   Champion decision vector: [310.798, -223.243, -448.787, -599.013, 227.253, ... ]
#   Champion fitness: [19347.9],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 8050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[213.385, -431.485, 119.46, 285.452, -59.3286, ... ]
#   	Fitness vector:		[17552.9]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[-472.758, 288.017, 359.483, 376.661, 583.289, ... ]
#   	Fitness vector:		[18337.8]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[-26.326, 266.464, 119.698, -130.212, 508.721, ... ]
#   	Fitness vector:		[18112.1]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[344.828, -90.2991, 121.896, -206.627, 279.726, ... ]
#   	Fitness vector:		[17910.6]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[253.254, 307.644, 456.696, 191.794, 403.169, ... ]
#   	Fitness vector:		[17269.8]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[73.6623, -126.212, 450.256, 106.223, 419.595, ... ]
#   	Fitness vector:		[18096.5]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[586.532, 27.703, 10.6137, -336.097, -169.598, ... ]
#   	Fitness vector:		[18736.3]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[552.341, 25.1751, 547.279, 186.054, -248.208, ... ]
#   	Fitness vector:		[18757]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[37.8748, 271.735, 594.673, -162.616, 598.508, ... ]
#   	Fitness vector:		[18624.2]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[563.572, 117.665, -114.23, 102.305, -144.907, ... ]
#   	Fitness vector:		[17488.3]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[-5.52529, -231.969, -278.873, -244.566, 288.647, ... ]
#   	Fitness vector:		[17240.9]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[-88.9854, -91.3667, -22.0489, -207.6, -300.613, ... ]
#   	Fitness vector:		[18791.3]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[224.596, 3.56793, -48.3495, -55.7544, 516.851, ... ]
#   	Fitness vector:		[18919.2]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[267.306, -403.246, 341.82, 156.481, 223.2, ... ]
#   	Fitness vector:		[18634]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[-61.7836, 155.688, 70.0716, -241.233, 456.008, ... ]
#   	Fitness vector:		[18679]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[310.798, -223.243, -448.787, -599.013, 227.253, ... ]
#   	Fitness vector:		[17868.2]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[594.779, -459.592, -138.773, -131.841, 163.802, ... ]
#   	Fitness vector:		[18866.4]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[-283.138, 235.27, 106.606, -299.342, 212.854, ... ]
#   	Fitness vector:		[18823.2]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[436.917, -282.651, 193.235, 174.683, -220.062, ... ]
#   	Fitness vector:		[19449]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[438.214, 269.714, 499.407, 175.423, 345.737, ... ]
#   	Fitness vector:		[17905.4]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[348.501, -223.899, 482.78, -382.898, 289.834, ... ]
#   	Fitness vector:		[18683.7]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[86.1545, -222.035, -136.236, 410.59, 428.571, ... ]
#   	Fitness vector:		[17320.3]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[103.241, 174.243, 257.015, 109.975, -395.548, ... ]
#   	Fitness vector:		[18578.4]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[336.3, 333.273, -429.068, 23.6227, -246.182, ... ]
#   	Fitness vector:		[17780.7]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[321.324, 473.943, -6.64654, 161.334, -154.035, ... ]
#   	Fitness vector:		[18487]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[565.808, -398.781, 328.909, 7.2345, -522.126, ... ]
#   	Fitness vector:		[19066.2]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[475.154, -274.989, 404.914, -188.161, 517.564, ... ]
#   	Fitness vector:		[18589.6]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[386.244, -397.563, 549.005, -89.9804, -36.3221, ... ]
#   	Fitness vector:		[17125.8]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[25.0624, -165.047, 142.728, 597.091, -253.964, ... ]
#   	Fitness vector:		[18768.1]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[485.931, -265.671, 167.656, 191.472, 9.25998, ... ]
#   	Fitness vector:		[18433.7]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[318.323, -547.992, 139.627, 86.027, 412.377, ... ]
#   	Fitness vector:		[18001.5]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[63.2258, -296.877, 92.2347, 124.585, 576.867, ... ]
#   	Fitness vector:		[17983]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[-405.675, -180.745, 208.006, -560.25, 387.666, ... ]
#   	Fitness vector:		[17891.8]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[394.299, 120.389, -207.878, -80.0199, 102.848, ... ]
#   	Fitness vector:		[18812.6]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[284.365, 41.4327, 35.3851, -157.992, -319.536, ... ]
#   	Fitness vector:		[17978.1]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[-251.27, 98.4699, -157.207, -293.215, -1.4166, ... ]
#   	Fitness vector:		[19494.3]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[426.036, -376.291, 480.435, -98.7319, 511.283, ... ]
#   	Fitness vector:		[16964.5]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[-63.6663, 230.126, 102.432, 419.946, 351.17, ... ]
#   	Fitness vector:		[15970.2]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[-214.893, -529.638, 266.341, -230.887, 230.098, ... ]
#   	Fitness vector:		[16334.5]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[276.435, 326.498, 239.201, 335.811, -204.932, ... ]
#   	Fitness vector:		[17939.1]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[-105.496, -450.496, 316.163, -202.415, -121.766, ... ]
#   	Fitness vector:		[18148.7]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[-352.838, -289.049, 470.6, -178.216, 190.479, ... ]
#   	Fitness vector:		[17709.8]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[216.513, -447.027, 201.62, -86.6687, 203.446, ... ]
#   	Fitness vector:		[17027.4]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[331.908, -149.956, -216.187, -312.974, 356.959, ... ]
#   	Fitness vector:		[18375.2]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[-194.522, 254.099, 373.268, 65.2054, 475.142, ... ]
#   	Fitness vector:		[19050]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[281.314, -277.341, 288.257, 1.56165, 339.958, ... ]
#   	Fitness vector:		[17059.9]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[-48.05, -358.575, 312.3, 143.761, 472.925, ... ]
#   	Fitness vector:		[17382.5]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[-597.366, 123.151, -193.547, 24.8455, 526.312, ... ]
#   	Fitness vector:		[18428.5]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[333.767, 41.3547, -239.044, -376.434, 202.255, ... ]
#   	Fitness vector:		[20005.4]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[435.714, -117.92, 115.652, 316.452, -454.729, ... ]
#   	Fitness vector:		[18893.1]
#
#   Champion decision vector: [-63.6663, 230.126, 102.432, 419.946, 351.17, ... ]
#   Champion fitness: [15970.2],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 12050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[213.385, -431.485, 119.46, -191.938, 405.544, ... ]
#   	Fitness vector:		[15026.6]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[346.133, -311.029, -140.913, -393.842, 336.673, ... ]
#   	Fitness vector:		[15432.2]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[-26.326, 266.464, 119.698, -130.212, 508.721, ... ]
#   	Fitness vector:		[15073.6]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[344.828, -90.2991, 121.896, -206.627, 279.726, ... ]
#   	Fitness vector:		[15443.2]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[98.6209, -9.74012, -324.293, 248.463, 255.69, ... ]
#   	Fitness vector:		[14385.2]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[73.6623, -126.212, 450.256, 106.223, 419.595, ... ]
#   	Fitness vector:		[14619.3]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[586.532, -30.7484, 147.785, 322.316, 195.856, ... ]
#   	Fitness vector:		[16277]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[552.341, 25.1751, 547.279, 186.054, 535.041, ... ]
#   	Fitness vector:		[16296.4]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[37.8748, 271.735, 594.673, 356.491, 298.4, ... ]
#   	Fitness vector:		[16222.8]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[527.615, 460.389, 510.343, 328.735, 573.424, ... ]
#   	Fitness vector:		[15222.3]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[527.683, -309.146, -513.274, -244.566, 288.647, ... ]
#   	Fitness vector:		[14117.8]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[504.878, 116.903, 272.266, -207.6, -300.613, ... ]
#   	Fitness vector:		[14592.3]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[394.333, -236.747, -501.384, -25.9161, 361.517, ... ]
#   	Fitness vector:		[15658.5]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[267.306, -403.246, 341.82, 156.481, 223.2, ... ]
#   	Fitness vector:		[14931.1]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[-61.7836, 155.688, 70.0716, -241.233, 456.008, ... ]
#   	Fitness vector:		[16361.6]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[310.798, -223.243, -448.787, -599.013, 227.253, ... ]
#   	Fitness vector:		[15549.9]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[594.779, -459.592, -138.773, 482.366, 262.52, ... ]
#   	Fitness vector:		[15575.5]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[442.534, -417.402, 149.161, -108.632, 269.36, ... ]
#   	Fitness vector:		[17007.6]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[436.917, -282.651, 193.235, 174.683, -220.062, ... ]
#   	Fitness vector:		[15637.2]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[448.611, -535.914, 499.407, 175.423, 345.737, ... ]
#   	Fitness vector:		[14958.1]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[348.501, -223.899, 482.78, -382.898, 289.834, ... ]
#   	Fitness vector:		[14700.7]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[86.1545, -222.035, -136.236, 410.59, 210.578, ... ]
#   	Fitness vector:		[15410.1]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[343.686, -373.235, 598.435, 27.7743, 532.19, ... ]
#   	Fitness vector:		[15019.3]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[563.033, -373.05, 76.5043, -229.471, 229.32, ... ]
#   	Fitness vector:		[15046.8]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[76.0807, -506.593, -370.409, -397.968, -145.397, ... ]
#   	Fitness vector:		[15688.1]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[565.808, -398.781, 328.909, 7.2345, -522.126, ... ]
#   	Fitness vector:		[16039.8]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[475.154, -274.989, 404.914, -502.939, 234.627, ... ]
#   	Fitness vector:		[14780.3]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[386.244, -397.563, 549.005, -89.9804, -36.3221, ... ]
#   	Fitness vector:		[14748.4]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[409.968, -382.666, 80.5456, -568.967, 542.269, ... ]
#   	Fitness vector:		[15886.2]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[291.927, -265.671, 167.656, 191.472, 9.25998, ... ]
#   	Fitness vector:		[15930.4]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[318.323, -547.992, 139.627, 86.027, 412.377, ... ]
#   	Fitness vector:		[15641.6]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[63.2258, -296.877, 92.2347, 124.585, 576.867, ... ]
#   	Fitness vector:		[14609.7]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[-405.675, -180.745, 208.006, -560.25, 387.666, ... ]
#   	Fitness vector:		[14985]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[167.052, -495.682, -160.876, 98.2738, 102.848, ... ]
#   	Fitness vector:		[15814.7]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[284.365, 41.4327, 35.3851, -157.992, 7.3473, ... ]
#   	Fitness vector:		[16057.8]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[545.981, -350.024, 498.78, 145.393, 303.073, ... ]
#   	Fitness vector:		[15918.2]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[426.036, -376.291, 480.435, -98.7319, 168.219, ... ]
#   	Fitness vector:		[14882.3]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[-374.316, 230.126, 102.432, 419.946, 351.17, ... ]
#   	Fitness vector:		[14773.1]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[216.163, -529.638, 266.341, -230.887, 230.098, ... ]
#   	Fitness vector:		[13956.3]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[180.069, -90.512, -373.888, 386.62, 422.834, ... ]
#   	Fitness vector:		[15714]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[-105.496, -450.496, 316.163, -202.415, -121.766, ... ]
#   	Fitness vector:		[15737.3]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[470.338, 61.2833, 520.569, 222.511, -3.66583, ... ]
#   	Fitness vector:		[15820.7]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[216.513, -447.027, 201.62, -86.6687, 203.446, ... ]
#   	Fitness vector:		[14512]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[331.908, -149.956, -216.187, -312.974, 402.128, ... ]
#   	Fitness vector:		[15619]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[-97.2995, -167.414, 373.268, 65.2054, 475.142, ... ]
#   	Fitness vector:		[15853.4]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[281.314, -277.341, 288.257, 1.56165, 339.958, ... ]
#   	Fitness vector:		[15630.2]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[-48.05, -358.575, 312.3, 143.761, 472.925, ... ]
#   	Fitness vector:		[13504]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[-597.366, 123.151, -193.547, 24.8455, 526.312, ... ]
#   	Fitness vector:		[15309.4]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[-181.316, 483.276, -156.031, -537.774, 478.847, ... ]
#   	Fitness vector:		[16766.5]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[435.714, -117.92, 115.652, 316.452, -246.158, ... ]
#   	Fitness vector:		[16678.4]
#
#   Champion decision vector: [-48.05, -358.575, 312.3, 143.761, 472.925, ... ]
#   Champion fitness: [13504],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 16050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[213.385, -431.485, 119.46, -191.938, 405.544, ... ]
#   	Fitness vector:		[12947.6]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[346.133, -311.029, -140.913, -393.842, 336.673, ... ]
#   	Fitness vector:		[13082.1]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[-26.326, 266.464, 119.698, -130.212, 508.721, ... ]
#   	Fitness vector:		[13661.7]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[344.828, -90.2991, 121.896, -206.627, 279.726, ... ]
#   	Fitness vector:		[13290.4]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[98.6209, -509.137, -324.293, 248.463, 255.69, ... ]
#   	Fitness vector:		[12092.3]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[73.6623, -126.212, 450.256, 106.223, 419.595, ... ]
#   	Fitness vector:		[12087.7]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[586.532, -30.7484, 147.785, 322.316, 195.856, ... ]
#   	Fitness vector:		[14509.8]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[552.341, -593.672, 226.779, 89.6166, 243.293, ... ]
#   	Fitness vector:		[13431.6]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[37.8748, 271.735, 594.673, 356.491, 298.4, ... ]
#   	Fitness vector:		[14206.9]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[527.615, 460.389, 510.343, 328.735, 573.424, ... ]
#   	Fitness vector:		[13792.6]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[527.683, -309.146, -513.274, -244.566, 288.647, ... ]
#   	Fitness vector:		[12614.4]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[504.878, 116.903, 272.266, -207.6, -300.613, ... ]
#   	Fitness vector:		[12958.4]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[78.3572, -11.9232, 140.962, -133.102, 242.443, ... ]
#   	Fitness vector:		[13995.7]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[267.306, -403.246, 341.82, 156.481, 223.2, ... ]
#   	Fitness vector:		[13536.1]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[-61.7836, 155.688, 70.0716, 170.44, 336.22, ... ]
#   	Fitness vector:		[13721.5]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[441.081, -565.578, -102.308, 155.92, 483.65, ... ]
#   	Fitness vector:		[13452.8]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[594.779, -459.592, -138.773, -457.829, 439.998, ... ]
#   	Fitness vector:		[13632.8]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[212.142, -560.466, 538.175, -48.1939, 180.302, ... ]
#   	Fitness vector:		[14584]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[436.917, -282.651, 193.235, 174.683, -220.062, ... ]
#   	Fitness vector:		[14502]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[588.681, -349.735, 499.407, 175.423, 345.737, ... ]
#   	Fitness vector:		[12789.9]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[218.313, 112.373, 304.457, -382.898, 289.834, ... ]
#   	Fitness vector:		[13020]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[86.1545, -222.035, -136.236, 410.59, 210.578, ... ]
#   	Fitness vector:		[13325.4]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[343.686, -373.235, 598.435, 27.7743, 532.19, ... ]
#   	Fitness vector:		[13131.8]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[563.033, -373.05, 76.5043, -229.471, 229.32, ... ]
#   	Fitness vector:		[13390.8]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[76.0807, -506.593, -370.409, -397.968, -145.397, ... ]
#   	Fitness vector:		[13156]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[565.808, -398.781, 202.921, 85.1675, 575.293, ... ]
#   	Fitness vector:		[13581]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[475.154, -274.989, 404.914, -502.939, 234.627, ... ]
#   	Fitness vector:		[13277]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[386.244, -397.563, 79.424, 52.7852, 181.823, ... ]
#   	Fitness vector:		[12630.7]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[409.968, -382.666, 80.5456, -568.967, 542.269, ... ]
#   	Fitness vector:		[13450.1]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[291.927, -265.671, 167.656, 191.472, 9.25998, ... ]
#   	Fitness vector:		[13405.5]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[318.323, -547.992, 139.627, 86.027, 412.377, ... ]
#   	Fitness vector:		[13625]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[63.2258, -296.877, 92.2347, 124.585, 576.867, ... ]
#   	Fitness vector:		[12781.7]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[-128.978, -490.796, 183.477, -34.2455, 447.697, ... ]
#   	Fitness vector:		[13123.8]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[167.052, -495.682, 223.422, 98.2738, 102.848, ... ]
#   	Fitness vector:		[13561.8]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[284.365, 41.4327, 35.3851, -157.992, 7.3473, ... ]
#   	Fitness vector:		[13343.8]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[545.981, -462.087, 207.078, 145.393, 303.073, ... ]
#   	Fitness vector:		[13990.5]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[426.036, -376.291, 480.435, -98.7319, 168.219, ... ]
#   	Fitness vector:		[13684.2]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[-374.316, 230.126, 102.432, 419.946, 351.17, ... ]
#   	Fitness vector:		[12556.2]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[216.163, -529.638, 266.341, -230.887, 230.098, ... ]
#   	Fitness vector:		[11580.3]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[278.151, -90.512, -373.888, 386.62, 422.834, ... ]
#   	Fitness vector:		[13241.4]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[-377.257, 194.521, -359.557, -14.7431, -7.6058, ... ]
#   	Fitness vector:		[13619.5]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[-216.582, 133.619, 412.267, 170.669, 402.104, ... ]
#   	Fitness vector:		[13917.1]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[216.513, -447.027, 201.62, -86.6687, 203.446, ... ]
#   	Fitness vector:		[12843.2]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[331.908, -149.956, -216.187, -312.974, 402.128, ... ]
#   	Fitness vector:		[14025.6]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[567.63, -3.04516, 300.802, 297.061, 475.142, ... ]
#   	Fitness vector:		[13232.7]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[281.314, -277.341, 288.257, 1.56165, 339.958, ... ]
#   	Fitness vector:		[14112]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[578.85, -166.19, 130.888, 376.411, 341.209, ... ]
#   	Fitness vector:		[12001.7]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[549.44, -277.833, 110.341, -132.008, -224.087, ... ]
#   	Fitness vector:		[13408.8]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[-181.316, -389.39, -156.031, -537.774, 478.847, ... ]
#   	Fitness vector:		[14722.3]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[435.714, -117.92, 115.652, 316.452, 284.143, ... ]
#   	Fitness vector:		[14557.9]
#
#   Champion decision vector: [216.163, -529.638, 266.341, -230.887, 230.098, ... ]
#   Champion fitness: [11580.3],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 20050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[213.385, -431.485, 119.46, -191.938, 405.544, ... ]
#   	Fitness vector:		[10437.2]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[346.133, -311.029, -140.913, -393.842, 336.673, ... ]
#   	Fitness vector:		[11806.7]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[-26.326, 266.464, 119.698, -130.212, 508.721, ... ]
#   	Fitness vector:		[12008.7]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[344.828, -265.849, 121.896, -206.627, 279.726, ... ]
#   	Fitness vector:		[12160.3]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[98.6209, -509.137, -324.293, 248.463, 255.69, ... ]
#   	Fitness vector:		[11179.3]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[73.6623, -126.212, 450.256, 106.223, 419.595, ... ]
#   	Fitness vector:		[10607.3]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[566.747, 89.4434, 473.042, -82.9305, 350.699, ... ]
#   	Fitness vector:		[12075.7]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[552.341, -593.672, 226.779, 89.6166, 243.293, ... ]
#   	Fitness vector:		[11625.6]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[525.514, -546.963, 240.941, -31.3093, 144.36, ... ]
#   	Fitness vector:		[12196.5]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[461.821, -210.912, 222.553, -370.488, 237.406, ... ]
#   	Fitness vector:		[11554.5]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[527.683, -309.146, -513.274, -244.566, 288.647, ... ]
#   	Fitness vector:		[11436.1]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[263.909, -302.391, -210.635, -88.4854, 207.446, ... ]
#   	Fitness vector:		[11532.4]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[78.3572, -11.9232, 140.962, -133.102, 242.443, ... ]
#   	Fitness vector:		[11997.8]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[267.306, -403.246, 341.82, 156.481, 223.2, ... ]
#   	Fitness vector:		[11500.5]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[-61.7836, 155.688, 70.0716, 170.44, 336.22, ... ]
#   	Fitness vector:		[11755.5]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[441.081, -565.578, -102.308, 155.92, 483.65, ... ]
#   	Fitness vector:		[11483.6]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[594.779, -459.592, -138.773, -457.829, 439.998, ... ]
#   	Fitness vector:		[12449]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[520.388, -524.423, 122.015, -56.5835, 416.893, ... ]
#   	Fitness vector:		[12744.6]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[436.917, -282.651, 193.235, -52.007, -220.062, ... ]
#   	Fitness vector:		[12098]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[588.681, -349.735, 499.407, 175.423, 345.737, ... ]
#   	Fitness vector:		[11463.6]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[218.313, 112.373, 304.457, -382.898, 289.834, ... ]
#   	Fitness vector:		[12178.8]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[86.1545, -222.035, -136.236, 410.59, 210.578, ... ]
#   	Fitness vector:		[11521.2]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[343.686, -373.235, 598.435, 27.7743, 532.19, ... ]
#   	Fitness vector:		[11721.8]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[563.033, -373.05, 76.5043, -229.471, 229.32, ... ]
#   	Fitness vector:		[12278.2]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[76.0807, -506.593, -370.409, -397.968, -145.397, ... ]
#   	Fitness vector:		[11871.8]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[565.808, -398.781, 202.921, 85.1675, 575.293, ... ]
#   	Fitness vector:		[11765]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[572.215, -426.956, 351.578, 116.76, 234.627, ... ]
#   	Fitness vector:		[10685.4]
#   #27:
#   	ID:			1498785260694045993
# ...
#   	Fitness vector:		[-161.854]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[530.503, -334.434, 128.992, -23.3928, 475.892, ... ]
#   	Fitness vector:		[-160.836]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[553.269, -326.84, 133.133, -12.1826, 488.346, ... ]
#   	Fitness vector:		[-160.567]
#
#   Champion decision vector: [557.929, -322.558, 138.815, -15.4801, 454.342, ... ]
#   Champion fitness: [-163.03],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 392050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[535.507, -327.065, 120.461, -2.20559, 477.152, ... ]
#   	Fitness vector:		[-161.785]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[554.763, -315.214, 127.818, -24.9497, 464.082, ... ]
#   	Fitness vector:		[-160.575]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[550.383, -309.418, 142.641, -25.8037, 464.663, ... ]
#   	Fitness vector:		[-162.948]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[558.05, -319.855, 115.211, 2.18238, 475.806, ... ]
#   	Fitness vector:		[-160.056]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[523.26, -331.129, 106.644, -13.2877, 476.531, ... ]
#   	Fitness vector:		[-161.624]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[557.929, -322.558, 138.815, -15.4801, 454.342, ... ]
#   	Fitness vector:		[-163.716]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[551.683, -324.329, 119.299, -8.35651, 492.594, ... ]
#   	Fitness vector:		[-161.413]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[536.206, -312.472, 104.745, -4.88865, 477.51, ... ]
#   	Fitness vector:		[-161.48]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[539.49, -332.749, 134.702, -32.925, 480.509, ... ]
#   	Fitness vector:		[-161.253]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[561.392, -305.603, 136.07, -21.9757, 452.782, ... ]
#   	Fitness vector:		[-160.539]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[540.709, -331.275, 151.641, -6.98292, 494.408, ... ]
#   	Fitness vector:		[-158.375]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[542.464, -321.681, 111.439, -7.50457, 453.052, ... ]
#   	Fitness vector:		[-161.967]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[544.835, -314.99, 126.283, -24.2693, 476.909, ... ]
#   	Fitness vector:		[-160.893]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[540.196, -312.873, 129.197, -24.5094, 484.795, ... ]
#   	Fitness vector:		[-162.763]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[544.969, -304.349, 121.385, -21.6467, 456.756, ... ]
#   	Fitness vector:		[-160.88]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[543.479, -299.276, 112.303, -3.05131, 457.078, ... ]
#   	Fitness vector:		[-161.294]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[537.33, -309.206, 120.681, 0.288662, 486.677, ... ]
#   	Fitness vector:		[-160.342]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[545.603, -311.402, 92.1842, -40.2063, 447.275, ... ]
#   	Fitness vector:		[-161.09]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[528.053, -331.612, 107.948, -4.73029, 454.054, ... ]
#   	Fitness vector:		[-161.116]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[538.018, -316.285, 138.232, -20.2828, 464.422, ... ]
#   	Fitness vector:		[-160.855]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[543.658, -301.818, 129.108, -14.1556, 464.039, ... ]
#   	Fitness vector:		[-161.163]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[561.6, -302.353, 142.665, -0.230379, 450.512, ... ]
#   	Fitness vector:		[-160.037]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[536.723, -301.237, 121.365, -15.6257, 431.772, ... ]
#   	Fitness vector:		[-160.862]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[535.391, -300.063, 114.267, -10.8227, 462.21, ... ]
#   	Fitness vector:		[-161.685]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[542.465, -297.76, 132.357, -13.1521, 463.672, ... ]
#   	Fitness vector:		[-160.064]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[555.231, -314.478, 111.904, -6.507, 481.145, ... ]
#   	Fitness vector:		[-160.677]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[521.572, -331.856, 115.477, -41.8404, 457.965, ... ]
#   	Fitness vector:		[-160.437]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[528.909, -311.047, 125.449, 2.63202, 460.386, ... ]
#   	Fitness vector:		[-159.542]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[538.383, -334.232, 109.19, -21.2363, 461.97, ... ]
#   	Fitness vector:		[-160.682]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[538.073, -316.262, 129.732, -36.6443, 472.281, ... ]
#   	Fitness vector:		[-161.14]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[538.156, -332.831, 154.417, 7.93103, 489.84, ... ]
#   	Fitness vector:		[-161.429]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[547.124, -338.283, 113.273, -25.2588, 461.682, ... ]
#   	Fitness vector:		[-162.023]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[526.639, -310.76, 106.624, 4.28341, 498.39, ... ]
#   	Fitness vector:		[-160.836]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[526.723, -322.06, 142.561, -4.08194, 463.576, ... ]
#   	Fitness vector:		[-160.333]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[546.315, -310.286, 122.088, -16.5726, 461.47, ... ]
#   	Fitness vector:		[-160.725]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[539.093, -331.336, 131.197, -1.54358, 482.766, ... ]
#   	Fitness vector:		[-162.128]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[537.992, -323.202, 147.959, -8.72272, 462.013, ... ]
#   	Fitness vector:		[-161.497]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[508.023, -324.015, 122.62, -16.0376, 441.484, ... ]
#   	Fitness vector:		[-161.104]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[532.798, -358.129, 125.074, -8.94669, 448.602, ... ]
#   	Fitness vector:		[-160.754]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[547.835, -306.598, 161.254, 3.67073, 477.97, ... ]
#   	Fitness vector:		[-160.042]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[536.516, -303.372, 134.966, -19.174, 448.288, ... ]
#   	Fitness vector:		[-162.452]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[537.371, -313.771, 114.379, -25.6928, 441.978, ... ]
#   	Fitness vector:		[-162.232]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[548.878, -335.235, 121.583, -30.9967, 485.039, ... ]
#   	Fitness vector:		[-159.634]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[534.063, -340.898, 119.415, -10.7734, 465.118, ... ]
#   	Fitness vector:		[-160.223]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[534.216, -343.078, 113.542, -11.2472, 476.308, ... ]
#   	Fitness vector:		[-161.938]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[565.983, -315.123, 114.502, -31.6333, 475.653, ... ]
#   	Fitness vector:		[-159.325]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[556.438, -335.659, 126.403, 2.03857, 448.738, ... ]
#   	Fitness vector:		[-162.264]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[530.617, -334.066, 120.295, -19.8222, 466.108, ... ]
#   	Fitness vector:		[-163.431]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[530.503, -334.434, 128.992, -23.3928, 475.892, ... ]
#   	Fitness vector:		[-161.356]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[553.269, -326.84, 133.133, -12.1826, 488.346, ... ]
#   	Fitness vector:		[-161.144]
#
#   Champion decision vector: [557.929, -322.558, 138.815, -15.4801, 454.342, ... ]
#   Champion fitness: [-163.716],
#   Problem name: Shifted Griewank Function
#   	Global dimension:			500
#   	Integer dimension:			0
#   	Fitness dimension:			1
#   	Number of objectives:			1
#   	Equality constraints dimension:		0
#   	Inequality constraints dimension:	0
#   	Lower bounds: [-600, -600, -600, -600, -600, ... ]
#   	Upper bounds: [600, 600, 600, 600, 600, ... ]
#
#   	Has gradient: false
#   	User implemented gradient sparsity: false
#   	Has hessians: false
#   	User implemented hessians sparsity: false
#
#   	Fitness evaluations: 396050
#
#   	Thread safety: none
#
#   Extra info:
#   	Dimensions: 500
#   Population size: 50
#
#   List of individuals:
#   #0:
#   	ID:			3926048254815250983
#   	Decision vector:	[535.507, -327.065, 120.461, -2.20559, 477.152, ... ]
#   	Fitness vector:		[-163.49]
#   #1:
#   	ID:			9131869432026946045
#   	Decision vector:	[554.763, -315.214, 127.818, -24.9497, 464.082, ... ]
#   	Fitness vector:		[-161.821]
#   #2:
#   	ID:			16790867024901231733
#   	Decision vector:	[550.383, -309.418, 142.641, -25.8037, 464.663, ... ]
#   	Fitness vector:		[-163.649]
#   #3:
#   	ID:			16307283267701041256
#   	Decision vector:	[558.05, -319.855, 115.211, 2.18238, 475.806, ... ]
#   	Fitness vector:		[-161.406]
#   #4:
#   	ID:			15579689882309474578
#   	Decision vector:	[523.26, -331.129, 106.644, -13.2877, 476.531, ... ]
#   	Fitness vector:		[-162.438]
#   #5:
#   	ID:			15621749793646528234
#   	Decision vector:	[557.929, -322.558, 138.815, -15.4801, 454.342, ... ]
#   	Fitness vector:		[-164.662]
#   #6:
#   	ID:			4891556337679482183
#   	Decision vector:	[551.683, -324.329, 119.299, -8.35651, 492.594, ... ]
#   	Fitness vector:		[-162.509]
#   #7:
#   	ID:			10384591773264894436
#   	Decision vector:	[536.206, -312.472, 104.745, -4.88865, 477.51, ... ]
#   	Fitness vector:		[-162.583]
#   #8:
#   	ID:			11473622497093314701
#   	Decision vector:	[539.49, -332.749, 134.702, -32.925, 480.509, ... ]
#   	Fitness vector:		[-163.469]
#   #9:
#   	ID:			15663351989330768530
#   	Decision vector:	[548.883, -323.718, 116.79, -22.9406, 489.346, ... ]
#   	Fitness vector:		[-162.338]
#   #10:
#   	ID:			5664723104702847343
#   	Decision vector:	[540.709, -331.275, 151.641, -6.98292, 494.408, ... ]
#   	Fitness vector:		[-159.749]
#   #11:
#   	ID:			3906790714307460839
#   	Decision vector:	[542.464, -321.681, 111.439, -7.50457, 453.052, ... ]
#   	Fitness vector:		[-162.94]
#   #12:
#   	ID:			16583119383257263152
#   	Decision vector:	[544.835, -314.99, 126.283, -24.2693, 476.909, ... ]
#   	Fitness vector:		[-162.325]
#   #13:
#   	ID:			7788565916550773406
#   	Decision vector:	[540.196, -312.873, 129.197, -24.5094, 484.795, ... ]
#   	Fitness vector:		[-163.571]
#   #14:
#   	ID:			7810129298234471312
#   	Decision vector:	[537.324, -314.603, 117.639, -11.9517, 461.44, ... ]
#   	Fitness vector:		[-162.491]
#   #15:
#   	ID:			6873848985321074059
#   	Decision vector:	[543.479, -322.539, 112.303, -3.05131, 457.078, ... ]
#   	Fitness vector:		[-161.916]
#   #16:
#   	ID:			1181625939929913453
#   	Decision vector:	[537.33, -309.206, 120.681, -24.259, 477.967, ... ]
#   	Fitness vector:		[-161.859]
#   #17:
#   	ID:			8812253282696678498
#   	Decision vector:	[545.603, -311.402, 117.813, 1.50896, 444.247, ... ]
#   	Fitness vector:		[-162.269]
#   #18:
#   	ID:			9056315291159916496
#   	Decision vector:	[528.053, -325.168, 107.948, -4.73029, 454.054, ... ]
#   	Fitness vector:		[-161.995]
#   #19:
#   	ID:			8755994031718489025
#   	Decision vector:	[538.018, -316.285, 138.232, -20.2828, 464.422, ... ]
#   	Fitness vector:		[-161.956]
#   #20:
#   	ID:			15469273509769274447
#   	Decision vector:	[543.658, -301.818, 129.108, -14.1556, 464.039, ... ]
#   	Fitness vector:		[-162.243]
#   #21:
#   	ID:			13156305589020254384
#   	Decision vector:	[561.6, -302.353, 142.665, -0.230379, 450.512, ... ]
#   	Fitness vector:		[-160.953]
#   #22:
#   	ID:			2071337546984113012
#   	Decision vector:	[536.723, -301.237, 121.365, -15.6257, 431.772, ... ]
#   	Fitness vector:		[-162.285]
#   #23:
#   	ID:			5534031138493432803
#   	Decision vector:	[535.391, -300.063, 114.267, -36.7925, 480.404, ... ]
#   	Fitness vector:		[-162.529]
#   #24:
#   	ID:			1611989688151042450
#   	Decision vector:	[542.465, -297.76, 132.357, -13.1521, 463.672, ... ]
#   	Fitness vector:		[-161.029]
#   #25:
#   	ID:			2552094580580899765
#   	Decision vector:	[523.369, -314.478, 111.904, -6.507, 481.145, ... ]
#   	Fitness vector:		[-162.08]
#   #26:
#   	ID:			17104127446128700891
#   	Decision vector:	[521.572, -331.856, 115.477, -41.8404, 457.965, ... ]
#   	Fitness vector:		[-162.062]
#   #27:
#   	ID:			1498785260694045993
#   	Decision vector:	[528.909, -311.047, 125.449, 2.63202, 460.386, ... ]
#   	Fitness vector:		[-160.6]
#   #28:
#   	ID:			17004832739026014812
#   	Decision vector:	[538.383, -334.232, 109.19, -21.2363, 461.97, ... ]
#   	Fitness vector:		[-161.59]
#   #29:
#   	ID:			12135069587537067032
#   	Decision vector:	[538.073, -316.262, 129.732, -36.6443, 472.281, ... ]
#   	Fitness vector:		[-162.206]
#   #30:
#   	ID:			14160341002297132672
#   	Decision vector:	[555.321, -341.31, 137.238, -6.78146, 461.031, ... ]
#   	Fitness vector:		[-162.289]
#   #31:
#   	ID:			13114162831834921219
#   	Decision vector:	[544.807, -325.051, 113.273, -25.2588, 461.682, ... ]
#   	Fitness vector:		[-162.852]
#   #32:
#   	ID:			13028728249618307950
#   	Decision vector:	[526.639, -310.76, 106.624, 4.28341, 498.39, ... ]
#   	Fitness vector:		[-162.649]
#   #33:
#   	ID:			5145335735589465148
#   	Decision vector:	[526.723, -322.06, 142.561, -4.08194, 463.576, ... ]
#   	Fitness vector:		[-161.623]
#   #34:
#   	ID:			7788023874865956012
#   	Decision vector:	[546.315, -310.286, 122.088, -16.5726, 461.47, ... ]
#   	Fitness vector:		[-161.518]
#   #35:
#   	ID:			15469461077948609808
#   	Decision vector:	[539.093, -331.336, 131.197, -1.54358, 482.766, ... ]
#   	Fitness vector:		[-163.703]
#   #36:
#   	ID:			2006905126227037006
#   	Decision vector:	[537.992, -323.202, 147.959, -8.72272, 462.013, ... ]
#   	Fitness vector:		[-162.531]
#   #37:
#   	ID:			17758704412847919790
#   	Decision vector:	[508.023, -324.015, 122.62, -16.0376, 441.484, ... ]
#   	Fitness vector:		[-162.493]
#   #38:
#   	ID:			14730383828231099334
#   	Decision vector:	[532.798, -358.129, 125.074, -8.94669, 448.602, ... ]
#   	Fitness vector:		[-161.663]
#   #39:
#   	ID:			12564464772112505661
#   	Decision vector:	[544.483, -318.11, 120.51, -34.6833, 477.97, ... ]
#   	Fitness vector:		[-161.286]
#   #40:
#   	ID:			15551860855384523624
#   	Decision vector:	[536.516, -303.372, 134.966, -19.174, 448.288, ... ]
#   	Fitness vector:		[-163.803]
#   #41:
#   	ID:			6804328972340733744
#   	Decision vector:	[537.371, -313.771, 114.379, -25.6928, 441.978, ... ]
#   	Fitness vector:		[-162.852]
#   #42:
#   	ID:			7034719682137629795
#   	Decision vector:	[548.878, -335.235, 121.583, -30.9967, 485.039, ... ]
#   	Fitness vector:		[-160.902]
#   #43:
#   	ID:			13890318750897221230
#   	Decision vector:	[534.063, -340.898, 119.415, -10.7734, 465.118, ... ]
#   	Fitness vector:		[-161.721]
#   #44:
#   	ID:			15398555043027126584
#   	Decision vector:	[534.216, -343.078, 113.542, -11.2472, 476.308, ... ]
#   	Fitness vector:		[-163.04]
#   #45:
#   	ID:			6297134422478526768
#   	Decision vector:	[565.983, -315.123, 114.502, -31.6333, 475.653, ... ]
#   	Fitness vector:		[-160.889]
#   #46:
#   	ID:			1910902294903554168
#   	Decision vector:	[556.438, -335.659, 126.403, 2.03857, 448.738, ... ]
#   	Fitness vector:		[-163.196]
#   #47:
#   	ID:			13903560267650001324
#   	Decision vector:	[530.617, -334.066, 120.295, -19.8222, 466.108, ... ]
#   	Fitness vector:		[-164.131]
#   #48:
#   	ID:			6822054294187383514
#   	Decision vector:	[530.503, -334.434, 128.992, -23.3928, 475.892, ... ]
#   	Fitness vector:		[-162.835]
#   #49:
#   	ID:			18215423444902912010
#   	Decision vector:	[547.036, -319.119, 123.253, -4.42502, 476.35, ... ]
#   	Fitness vector:		[-162.355]
#
#   Champion decision vector: [557.929, -322.558, 138.815, -15.4801, 454.342, ... ]
#   Champion fitness: [-164.662]])

# %%
x_val = [x[2] for x in test2[0]]
y_val = [x[1] for x in test2[0]]
plt.plot(x_val,y_val)
plt.xlabel('Time in seconds', fontsize=12)
plt.ylabel('Fitness', fontsize=12)
plt.title('Shifted Greiwank Function D = 500 using Differential Evolution', fontsize=13)
plt.show()

# %%
print(test1[1][2].champion_f,test1[1][2].champion_x)
print(test2[1][60].champion_f,test2[1][60].champion_x)
# Out:
# [-30.15456923] [ 435.36390283 -274.79442356  -14.25668534  273.76627311  578.13679375
#   380.83739397   12.04135794 -534.76838122  384.25434119   89.15880718
#    -7.26203694  370.44527365  540.20290319  312.00811875 -425.60940207
#  -148.10800998  591.82326033  487.03706276 -102.39795175  509.21216282
#  -399.81509508 -234.71612098  593.44815883 -496.31162465 -381.16044272
#  -306.40152881 -393.92436138   22.37984643 -327.9137136  -457.20283512
#  -333.74179287   77.66820383 -192.50177644  443.32613879  -63.01846094
#  -260.54603903  397.46678011   25.60000414 -320.41765459  261.87667005
#   576.22896842 -569.62815105  200.59685718  -33.21407629  243.10446119
#   213.13286228  258.45687021  -61.30019517  -94.33231572 -346.32372453]
# [3.51937654] [ 512.54691057 -294.33251283  132.78840952  -61.20008766  442.97777242
#   312.71044061 -128.67896825 -542.20741709  407.15943524 -142.07032335
#   106.96135151  345.03540602  531.30425058  262.30386151 -357.37888969
#   -75.34008935  566.15359379  494.74926017  -81.44472877  477.57949108
#  -532.52337104 -171.14689498  354.4388171  -586.31886929 -484.2037836
#  -341.16159245 -318.92741633  -11.33729048 -202.01725917 -382.5172285
#  -566.04030761  335.59894656 -166.56726259  572.14849631    4.54236038
#  -127.08346979  422.24910726    8.5086374  -427.11877598  148.93432743
#   422.42559636 -577.62808834  270.55269728 -182.88530976  452.78650751
#    14.34267315  230.68636055  -44.755285   -237.9728685  -450.05161094
#  -345.36187664  262.81713707 -242.39934139   29.91945511 -442.26411415
#   278.33492494 -133.58490915  416.39048981  393.30604458   64.10046695
#    -4.74617801  481.24376955  334.45599604  171.78518993  431.85004153
